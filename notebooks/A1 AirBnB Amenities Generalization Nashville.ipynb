# %% [markdown]
# # 1.Import Dependencies

# %%
import pandas as pd
import numpy as np
import re
import plotly.express as px
import spacy
import nltk
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import os
import zipfile
import json
import copy

# %%
# # uncomment to download package
# nltk.download('stopwords')

# %%
# # uncomment to download package
# !python3 -m spacy download en_core_web_md

# %%
# # uncomment to download package
# !python3 -m spacy download en_core_web_lg

# %% [markdown]
# # 2.Define Helper Functions

# %%
def spacy_vectorizer(amenity, spacyModel):
  vec = spacyModel(amenity)

  return vec

def findEntities(doc):
  entities = []
  if len(doc.ents) > 0:
    for ent in doc.ents:
      if ent.label_=='ORG':
        entities.append(ent)
  return entities

def entityCorrections(entities, errors):
  fin_entities = []
  if entities:
    for entity in entities:
      if entity.text not in errors:
        fin_entities.append(entity)

  return fin_entities


def fetch_pos(entities):
  start = None
  end = None
  positions = []
  for entity in entities:
    positions.append([entity.start_char, entity.end_char])

  # flatten
  flat_pos = [item for sublist in positions for item in sublist]

  # print(positions)
  # print(flat_pos)

  return flat_pos

def fetch_slices(flat_pos, amenity):
  start=False

  slices = []
  for index in range(len(amenity)):  
    if index in flat_pos and not start:
      slices.append('|')
      slices.append(index)
      start=True

    elif index in flat_pos and start:
      slices.append(index)
      slices.append('|')
      start=False

    else:
      slices.append(index)
    
  # print(slices)

  return slices

def split_pipe(slices):
  indices_str = [str(index) if type(index) is int else index for index in slices]
  splits = [line.split(',') for line in (',').join(indices_str).split('|')]

  # print(splits)

  return splits

def clean_splits(splits):
  final_splits = []
  for split in splits:
    fin_split = []
    for index in split:
      if index!='':
        fin_split.append(int(index))
    final_splits.append(fin_split)

  # print(final_splits)

  return final_splits

def fetch_keep_words(final_splits, flat_pos):
  keep_words = []
  for split in final_splits:
    if split:
      if split[0] not in flat_pos:
        keep_words.append(split)

  # print(keep_words)

  return keep_words

def fetch_final_slices(keep_words):
  final_slices = []
  for piece in keep_words:
    if len(piece)>1:
      final_slices.append([piece[0], piece[-1]])
    else:
      final_slices.append(piece)

  # print(final_slices)

  return final_slices

def build_new_amenity(final_slices, amenity):
  new_amenity = ''
  
  i = 0
  j = len(final_slices) - 1 # 0 based index
  for piece in final_slices:
    if len(piece)>1:
      if i >= j:
        new_amenity += amenity[piece[0]:piece[1]+1]
      else:
        new_amenity += amenity[piece[0]:piece[1]]
    else:
      new_amenity += amenity[piece[0]]
    i+=1

  # print(new_amenity)

  return new_amenity

def removeEntities(amenity, entities):
  fin_amenity=None
  new_amenity=''

  if len(entities)>0:

    # fetch start and end positions for each entity
    flat_pos = fetch_pos(entities)

    # determine slices for strings which are not entities
    slices = fetch_slices(flat_pos, amenity)

    # split by '|'
    splits = split_pipe(slices)

    # cleanup splits
    final_splits = clean_splits(splits)

    # determine which splits to keep
    keep_words = fetch_keep_words(final_splits, flat_pos)

    # convert splits to ranges
    final_slices = fetch_final_slices(keep_words)

    # build new amenity name
    new_amenity = build_new_amenity(final_slices, amenity)

  if new_amenity!='':
    fin_amenity=new_amenity
  else:
    fin_amenity=amenity

  fin_amenity = str.strip(fin_amenity)

  return fin_amenity


def split_strucute(amenity):
  return re.split('(\s\–\s|\s-\s|\:)', amenity)[0]

def remove_number(amenity):
  return re.sub('[\d*]', '', amenity)

def alphanumeric(amenity):
  amenity_alnum = []
  for token in re.split('\s', amenity):
    if re.fullmatch('\w+', token):
      amenity_alnum.append(token)
  
  new_amenity = (' ').join(amenity_alnum)

  return new_amenity

def stem(amenity):
  amenity_stem = []
  ps = PorterStemmer()

  for token in re.split('\s', amenity):
    amenity_stem.append(ps.stem(token))
  
  new_amenity = (' ').join(amenity_stem)

  return new_amenity

def low_case(amenity):
  amenity_low = (' ').join([token.lower() for token in amenity.split()])

  return amenity_low

def remove_stopwords(amenity):
  amenity_no_stopwords = []
  stop_words = set(stopwords.words('english'))

  for token in amenity.split():
    if token not in stop_words:
      amenity_no_stopwords.append(token)
  new_amenity = (' ').join(amenity_no_stopwords)

  return new_amenity

# %%
# https://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

def find_silhouette(X, k_min, k_max, step=1, area_plot_only=False):
  range_n_clusters = list(range(k_min, k_max+1, step))

  for n_clusters in range_n_clusters:
      # Create a subplot with 1 row and 2 columns
      if not area_plot_only:
        fig, (ax1, ax2) = plt.subplots(1, 2)
      else:
        fig, ax1 = plt.subplots(1, 1)

      fig.set_size_inches(15, 15)

      # The 1st subplot is the silhouette plot
      # The silhouette coefficient can range from -1, 1 but in this example all
      # lie within [-0.1, 1]
      ax1.set_xlim([-0.1, 1])
      # The (n_clusters+1)*10 is for inserting blank space between silhouette
      # plots of individual clusters, to demarcate them clearly.
      ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

      # Initialize the clusterer with n_clusters value and a random generator
      # seed of 10 for reproducibility.
      clusterer = KMeans(n_clusters=n_clusters, n_init="auto", random_state=42)
      cluster_labels = clusterer.fit_predict(X)

      # The silhouette_score gives the average value for all the samples.
      # This gives a perspective into the density and separation of the formed
      # clusters
      silhouette_avg = silhouette_score(X, cluster_labels)
      print(
          "For n_clusters =",
          n_clusters,
          "The average silhouette_score is :",
          silhouette_avg,
      )

      # Compute the silhouette scores for each sample
      sample_silhouette_values = silhouette_samples(X, cluster_labels)

      y_lower = 10
      for i in range(n_clusters):
          # Aggregate the silhouette scores for samples belonging to
          # cluster i, and sort them
          ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

          ith_cluster_silhouette_values.sort()

          size_cluster_i = ith_cluster_silhouette_values.shape[0]
          y_upper = y_lower + size_cluster_i

          color = cm.nipy_spectral(float(i) / n_clusters)
          ax1.fill_betweenx(
              np.arange(y_lower, y_upper),
              0,
              ith_cluster_silhouette_values,
              facecolor=color,
              edgecolor=color,
              alpha=0.7,
          )

          # Label the silhouette plots with their cluster numbers at the middle
          ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i), fontsize=16)

          # Compute the new y_lower for next plot
          y_lower = y_upper + 10  # 10 for the 0 samples

      ax1.set_title("The silhouette plot for the various clusters.", fontsize=16)
      ax1.set_xlabel("The silhouette coefficient values", fontsize=20)
      ax1.set_ylabel("Cluster label", fontsize=20)

      # The vertical line for average silhouette score of all the values
      ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

      ax1.set_yticks([])  # Clear the yaxis labels / ticks
      ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
      ax1.set_xticklabels(ax1.get_xticks(), size=16)

      # 2nd Plot showing the actual clusters formed
      if not area_plot_only:
        colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
        ax2.scatter(
            X[:, 0], X[:, 1], marker=".", s=30, lw=0, alpha=0.7, c=colors, edgecolor="k"
        )

        # Labeling the clusters
        centers = clusterer.cluster_centers_
        # Draw white circles at cluster centers
        ax2.scatter(
            centers[:, 0],
            centers[:, 1],
            marker="o",
            c="white",
            alpha=1,
            s=200,
            edgecolor="k",
        )

        for i, c in enumerate(centers):
            ax2.scatter(c[0], c[1], marker="$%d$" % i, alpha=1, s=50, edgecolor="k")

        ax2.set_title("The visualization of the clustered data.")
        ax2.set_xlabel("Feature space for the 1st feature")
        ax2.set_ylabel("Feature space for the 2nd feature")

      plt.suptitle(
          "Silhouette analysis for KMeans clustering on sample data with n_clusters = %d"
          % n_clusters,
          fontsize=18,
          fontweight="bold",
      )

  plt.tight_layout()


  plt.savefig("silhouette.png",
            bbox_inches ="tight",
            pad_inches = 0.1,
            transparent = True,
            facecolor ="w",
            edgecolor ='w',
            orientation ='landscape')


  plt.show()

# %% [markdown]
# # 3.Import Datasets

# %%
# with zipfile.ZipFile('./listings.zip', 'r') as zip_ref:
#   try:
#     zip_ref.extractall('./')
#     if 'listings.csv' not in os.listdir('./'):
#         raise Exception('Failed to unzip files')
#     else:
#       print('Unzipped files')
#   except:
#     print('Failed to unzip files')
# Out:
# Unzipped files

# %%
# personal directory
# det_list_df = pd.read_csv('./listings.csv', dtype={'id':str}) 

# GitHub directory
det_list_df = pd.read_csv('../data/raw/AirBnB/Samples/listings.csv', dtype={'id':str})

# %%
amenities = det_list_df['amenities']

# %%
amenities.sample().values
# Out:
# array(['["First aid kit", "Oven", "Free street parking", "Fire extinguisher", "Wifi", "Hair dryer", "Shampoo", "Cooking basics", "Toaster", "Private entrance", "Microwave", "Dishwasher", "Long term stays allowed", "Extra pillows and blankets", "Refrigerator", "Heating", "Carbon monoxide alarm", "Hangers", "Essentials", "Hot water", "Dryer", "Freezer", "Keypad", "Iron", "Coffee maker", "Self check-in", "Paid parking off premises", "Washer", "Dedicated workspace", "Bed linens", "TV", "Stove", "Smoke alarm", "Pets allowed", "City skyline view", "Elevator", "Kitchen", "Air conditioning", "Dishes and silverware", "Blender", "Ceiling fan"]'],
#       dtype=object)

# %%
# convert 'amenities' column from JSON Object to list
decoded_amenities = amenities.apply(lambda x: json.loads(x))

# %%
decoded_amenities.sample().values
# Out:
# array([list(['First aid kit', 'Free street parking', 'Free parking on premises', 'Fire extinguisher', 'Wifi', 'Hair dryer', 'Shampoo', 'Cooking basics', 'Private entrance', 'Breakfast', 'Microwave', 'Long term stays allowed', 'Refrigerator', 'Heating', 'Carbon monoxide alarm', 'Hangers', 'Essentials', 'Hot water', 'Freezer', 'Keypad', 'Iron', 'Self check-in', 'TV', 'Backyard', 'Smoke alarm', 'Kitchen', 'Air conditioning', 'Coffee maker: Keurig coffee machine', 'Dishes and silverware'])],
#       dtype=object)

# %%
amenities_unique = set()

for amenities_listing in decoded_amenities:
  amenities_unique.update(set(amenities_listing))

# %%
print(len(amenities_unique))
# Out:
# 3017

# %%
list(amenities_unique)[:50]
# Out:
# ['Bluetooth speakers sound system with Bluetooth and aux',
#  'Fast wifi – 806 Mbps',
#  'Marshall Standmore II Bluetooth sound system',
#  '32" HDTV with Apple TV',
#  'Toaster Oven oven',
#  'GE Cafe stainless steel gas stove',
#  'Fast wifi – 718 Mbps',
#  'Ginger Lily Farms shampoo',
#  '60" HDTV with Apple TV, Roku, Fire TV, Amazon Prime Video, Hulu, Disney+, premium cable, Netflix',
#  'Dryer –\xa0In unit',
#  'Dedicated workspace',
#  'HDTV with Chromecast, HBO Max, Hulu, Amazon Prime Video, Roku, Fire TV, Disney+, Netflix, Apple TV',
#  '65" HDTV with Amazon Prime Video, HBO Max, Netflix, premium cable, Roku, Disney+, Hulu',
#  'Plaine Products (zero-waste and vegan) shampoo',
#  '43" HDTV with Amazon Prime Video, Apple TV, Netflix, standard cable',
#  'Coffee maker: drip coffee maker, french press',
#  '56" HDTV with Hulu, Netflix, DVD player, standard cable, Apple TV',
#  'Wifi – 42 Mbps',
#  'Fast wifi – 391 Mbps',
#  'TV with standard cable, Apple TV',
#  'TRADER JOES shampoo',
#  'Fast wifi – 437 Mbps',
#  'Game console: PS4 and Xbox Series X',
#  '60" HDTV with standard cable',
#  'Everyone Soap 3-in-1 body soap',
#  'Private hot tub - available all year',
#  'Fast wifi – 661 Mbps',
#  'Shared outdoor pool - available all year, saltwater',
#  'Pack ’n play/Travel crib',
#  '58" HDTV with Netflix',
#  'Dial body soap',
#  'Coffee maker: espresso machine, french press, Nespresso, pour-over coffee',
#  'Standard gas stove',
#  'Beekman body soap',
#  '52" TV with Amazon Prime Video, Disney+, Netflix',
#  '55" HDTV with Amazon Prime Video, Apple TV, Disney+, Hulu, Netflix, Roku',
#  'STAINLESS STEEL refrigerator',
#  'Smart lock',
#  'Argan Oil of Morocco, OGX shampoo',
#  'Different types conditioner',
#  '55" HDTV with HBO Max, Hulu, Netflix, standard cable',
#  'Pyle Bluetooth sound system',
#  '55" HDTV with Fire TV, standard cable, Amazon Prime Video, Netflix',
#  '50" HDTV with Amazon Prime Video, Chromecast, HBO Max, Netflix, Roku',
#  '42" HDTV with Amazon Prime Video, standard cable',
#  'Free parking on premises',
#  'TV with Roku, DVD player',
#  'Four Seasons shampoo',
#  '42" TV with standard cable, Amazon Prime Video, Roku, HBO Max, Disney+, Netflix, Hulu, Apple TV, Fire TV, Chromecast',
#  '32" HDTV']

# %% [markdown]
# # 4.Generalize Amenities

# %% [markdown]
# ## Resources
# * **1. Amenity Categories**
#   * [The amenities guests want by AirBnB](https://www.airbnb.com/resources/hosting-homes/a/the-amenities-guests-want-25)
#
# * **2. Product Name Generalization Workflow**
#   * [Product Clustering: A Text Clustering Approach](https://medium.com/moosend-engineering-data-science/product-clustering-a-text-clustering-approach-c392c2ef4310)
#   * [How to Practice Word2Vec for NLP Using Python](https://builtin.com/machine-learning/nlp-word2vec-python)
#
# * **3. Models from spaCy**
#   * [Available trained pipelines for English](https://spacy.io/models/en)
#
# * **4. Word Vectors and Semantic Similarity from spaCy**
#   * [Word vectors and semantic similarity](https://spacy.io/usage/linguistic-features#vectors-similarity)
#
# * **5. Named Entity Recognition**
#   * [Named Entity Recognition from spaCy](https://spacy.io/usage/spacy-101#annotations-ner)
#   * [Data Dictionary](https://www.kaggle.com/code/curiousprogrammer/entity-extraction-and-classification-using-spacy)
#
# * **6. Text Preprocessing**
#   * [Must Known Techniques for text preprocessing in NLP](https://www.analyticsvidhya.com/blog/2021/06/must-known-techniques-for-text-preprocessing-in-nlp/)
#   * [NLP- Text Preprocessing Techniques](https://medium.com/swlh/nlp-text-preprocessing-techniques-ea34d3f84de4)
#
# * **7. OHE Amenity Categories**
#   * [OHE Amenities](https://stackoverflow.com/questions/45312377/how-to-one-hot-encode-from-a-pandas-column-containing-a-list)

# %% [markdown]
# ## 1.Named Entity Recognition (N.E.R) Tokens versus Tokens in spaCy

# %%
nlp_md = spacy.load('en_core_web_md')

# %%
nlp_lg = spacy.load('en_core_web_lg')

# %%
doc = nlp_lg('55" HDTV with Amazon Prime Video, Apple TV, Netflix')

# %%
# practice fetching entities with the doc.ents attribute
for ent in doc.ents:
    print(
        """
        text:{}
        start_char:{}
        end_char:{}
        label:{}
        """.format(ent.text, ent.start_char, ent.end_char, ent.label_))
# Out:
#         text:55
#         start_char:0
#         end_char:2
#         label:CARDINAL
#
#
#         text:Amazon Prime Video
#         start_char:14
#         end_char:32
#         label:ORG
#
#
#         text:Apple TV
#         start_char:34
#         end_char:42
#         label:ORG
#
#
#         text:Netflix
#         start_char:44
#         end_char:51
#         label:ORG

# %%
# practice fetching entities with the doc.token attribute
for token in doc:
  print(
      """
      text: {}
      lemma_: {},
      ent_type_: {},
      pos_: {}
      tag_: {}
      dep_: {}
      shape_: {}
      is_alpha: {}
      is_stop: {}
      """.format(token.text, token.lemma_, token.ent_type_, token.pos_, token.tag_, token.dep_, token.shape_, token.is_alpha, token.is_stop))
# Out:
#       text: 55
#       lemma_: 55,
#       ent_type_: CARDINAL,
#       pos_: NUM
#       tag_: CD
#       dep_: nummod
#       shape_: dd
#       is_alpha: False
#       is_stop: False
#
#
#       text: "
#       lemma_: ",
#       ent_type_: ,
#       pos_: PUNCT
#       tag_: ``
#       dep_: punct
#       shape_: "
#       is_alpha: False
#       is_stop: False
#
#
#       text: HDTV
#       lemma_: hdtv,
#       ent_type_: ,
#       pos_: NOUN
#       tag_: NN
#       dep_: ROOT
#       shape_: XXXX
#       is_alpha: True
#       is_stop: False
#
#
#       text: with
#       lemma_: with,
#       ent_type_: ,
#       pos_: ADP
#       tag_: IN
#       dep_: prep
#       shape_: xxxx
#       is_alpha: True
#       is_stop: True
#
#
#       text: Amazon
#       lemma_: Amazon,
#       ent_type_: ORG,
#       pos_: PROPN
#       tag_: NNP
#       dep_: compound
#       shape_: Xxxxx
#       is_alpha: True
#       is_stop: False
#
#
#       text: Prime
#       lemma_: Prime,
#       ent_type_: ORG,
#       pos_: PROPN
#       tag_: NNP
#       dep_: compound
#       shape_: Xxxxx
#       is_alpha: True
#       is_stop: False
#
#
#       text: Video
#       lemma_: Video,
#       ent_type_: ORG,
#       pos_: PROPN
#       tag_: NNP
#       dep_: pobj
#       shape_: Xxxxx
#       is_alpha: True
#       is_stop: False
#
#
#       text: ,
#       lemma_: ,,
#       ent_type_: ,
#       pos_: PUNCT
#       tag_: ,
#       dep_: punct
#       shape_: ,
#       is_alpha: False
#       is_stop: False
#
#
#       text: Apple
#       lemma_: Apple,
#       ent_type_: ORG,
#       pos_: PROPN
#       tag_: NNP
#       dep_: compound
#       shape_: Xxxxx
#       is_alpha: True
#       is_stop: False
#
#
#       text: TV
#       lemma_: TV,
#       ent_type_: ORG,
#       pos_: PROPN
#       tag_: NNP
#       dep_: conj
#       shape_: XX
#       is_alpha: True
#       is_stop: False
#
#
#       text: ,
#       lemma_: ,,
#       ent_type_: ,
#       pos_: PUNCT
#       tag_: ,
#       dep_: punct
#       shape_: ,
#       is_alpha: False
#       is_stop: False
#
#
#       text: Netflix
#       lemma_: Netflix,
#       ent_type_: ORG,
#       pos_: PROPN
#       tag_: NNP
#       dep_: appos
#       shape_: Xxxxx
#       is_alpha: True
#       is_stop: False

# %% [markdown]
# ## 2.Create Catalog of Amenities

# %%
amenity_index = list(range(1, len(amenities_unique)+1))
amenity_index_str = ['a'+str(index) for index in amenity_index]

# %%
amenities_catalog = dict(zip(amenity_index_str, sorted(amenities_unique)))

# %%
for key in list(amenities_catalog.keys())[0:70]:
  print('{}: {}'.format(key, amenities_catalog[key]))
# Out:
# a1:  GE stove
# a2:  Small bluetooth speaker Bluetooth sound system
# a3: "Everyone" and a local non-profit bar of soap. body soap
# a4: "Everyone" shampoo
# a5: 1 burner portable induction glass stove top induction stove
# a6: 1" HDTV with Disney+, Hulu
# a7: 1" HDTV with Disney+, Hulu, Roku
# a8: 1/2 size in kitchenette with separate freezer and mini fridge in one bedroom refrigerator
# a9: 100" TV with Roku, Hulu, Amazon Prime Video, Netflix, Apple TV, HBO Max
# a10: 108" HDTV with Amazon Prime Video, Netflix, Roku, standard cable
# a11: 120" HDTV with Disney+, Apple TV, Netflix, premium cable, Amazon Prime Video
# a12: 19" TV
# a13: 2 burner cooktop oven
# a14: 2 burner glass induction stove top induction stove
# a15: 2 burner glass top stove electric stove
# a16: 2 burner induction glass stove top induction stove
# a17: 2 burners induction stove
# a18: 2 in 1 shampoo and conditioner conditioner
# a19: 20" HDTV
# a20: 20" HDTV with Fire TV
# a21: 20" compact smoothtop electric stove  oven
# a22: 21" HDTV with Roku, Netflix
# a23: 24" HDTV with Roku
# a24: 24" TV
# a25: 24" TV with Amazon Prime Video, Netflix
# a26: 25" HDTV with Netflix
# a27: 27" HDTV with Hulu, Netflix
# a28: 3 in 1 arm and hammer shower gel.shampo and conditioner shampoo
# a29: 3 in 1 conditioner
# a30: 3 in 1 organic  conditioner
# a31: 3 in 1 organic  shampoo
# a32: 3 in 1 shampoo
# a33: 3 in 1. shower gel. shampoo.conditioner body soap
# a34: 30" HDTV with Amazon Prime Video, Netflix, Roku, standard cable
# a35: 30" HDTV with HBO Max, Hulu, Netflix, Roku
# a36: 30" HDTV with HBO Max, premium cable, Fire TV, Amazon Prime Video, Netflix, standard cable, Hulu
# a37: 30" HDTV with Roku
# a38: 30" HDTV with Roku, Disney+, standard cable, Hulu, Netflix
# a39: 30" TV with Roku
# a40: 31" HDTV with Roku
# a41: 32" HDTV
# a42: 32" HDTV with Amazon Prime Video, Chromecast, Disney+, Hulu, Netflix
# a43: 32" HDTV with Amazon Prime Video, Disney+, Hulu, Netflix, Roku
# a44: 32" HDTV with Amazon Prime Video, Netflix, Roku
# a45: 32" HDTV with Amazon Prime Video, Roku
# a46: 32" HDTV with Apple TV
# a47: 32" HDTV with Disney+, HBO Max, Hulu, Netflix, Amazon Prime Video
# a48: 32" HDTV with Disney+, HBO Max, Netflix, Apple TV, Roku, Hulu, Amazon Prime Video
# a49: 32" HDTV with Disney+, Hulu
# a50: 32" HDTV with Fire TV, Hulu, Netflix
# a51: 32" HDTV with HBO Max, Amazon Prime Video, Hulu, Netflix, Apple TV, Disney+
# a52: 32" HDTV with Hulu, Netflix, Amazon Prime Video
# a53: 32" HDTV with Hulu, Netflix, Roku
# a54: 32" HDTV with Hulu, Roku
# a55: 32" HDTV with Netflix
# a56: 32" HDTV with Netflix, HBO Max, Apple TV, standard cable
# a57: 32" HDTV with Roku
# a58: 32" HDTV with Roku, Chromecast, Amazon Prime Video, Apple TV, Disney+, Fire TV, Hulu, HBO Max, Netflix
# a59: 32" HDTV with premium cable, Roku
# a60: 32" HDTV with standard cable
# a61: 32" HDTV with standard cable, Roku
# a62: 32" TV
# a63: 32" TV with Amazon Prime Video, Hulu, Netflix
# a64: 32" TV with Disney+, Hulu, Netflix, Roku
# a65: 32" TV with Fire TV
# a66: 32" TV with Netflix
# a67: 32" TV with Netflix, DVD player, Roku
# a68: 32" TV with Roku
# a69: 32" TV with Roku, standard cable
# a70: 34" TV with HBO Max, Disney+, Netflix, premium cable, Roku, Hulu, Amazon Prime Video

# %% [markdown]
# ## 3.Vectorize Amenities

# %%
import copy

amenities_catalog_copy = copy.deepcopy(amenities_catalog)

amenities_catalog = {}
for key in amenities_catalog_copy.keys():
  amenities_catalog[key]={'string':amenities_catalog_copy[key]}

# %%
for key in amenities_catalog.keys():
  amenities_catalog[key]['spacyVector']=spacy_vectorizer(amenities_catalog[key]['string'], nlp_lg)

# %%
for key in list(amenities_catalog.keys())[:5]:
  print('{}: {}\n'.format(key, amenities_catalog[key]))
# Out:
# a1: {'string': ' GE stove', 'spacyVector':  GE stove}
#
# a2: {'string': ' Small bluetooth speaker Bluetooth sound system', 'spacyVector':  Small bluetooth speaker Bluetooth sound system}
#
# a3: {'string': '"Everyone" and a local non-profit bar of soap. body soap', 'spacyVector': "Everyone" and a local non-profit bar of soap. body soap}
#
# a4: {'string': '"Everyone" shampoo', 'spacyVector': "Everyone" shampoo}
#
# a5: {'string': '1 burner portable induction glass stove top induction stove', 'spacyVector': 1 burner portable induction glass stove top induction stove}

# %% [markdown]
# ## 4.Get ORG Type Recognized Entities

# %%
for key in amenities_catalog.keys():
  amenities_catalog[key]['entities'] = findEntities( amenities_catalog[key]['spacyVector'])

# %%
for amenitiy in list(amenities_catalog.values())[25:50]:
  print('{}\n'.format(amenitiy))
# Out:
# {'string': '25" HDTV with Netflix', 'spacyVector': 25" HDTV with Netflix, 'entities': [Netflix]}
#
# {'string': '27" HDTV with Hulu, Netflix', 'spacyVector': 27" HDTV with Hulu, Netflix, 'entities': [Hulu, Netflix]}
#
# {'string': '3 in 1 arm and hammer shower gel.shampo and conditioner shampoo', 'spacyVector': 3 in 1 arm and hammer shower gel.shampo and conditioner shampoo, 'entities': []}
#
# {'string': '3 in 1 conditioner', 'spacyVector': 3 in 1 conditioner, 'entities': []}
#
# {'string': '3 in 1 organic  conditioner', 'spacyVector': 3 in 1 organic  conditioner, 'entities': []}
#
# {'string': '3 in 1 organic  shampoo', 'spacyVector': 3 in 1 organic  shampoo, 'entities': []}
#
# {'string': '3 in 1 shampoo', 'spacyVector': 3 in 1 shampoo, 'entities': []}
#
# {'string': '3 in 1. shower gel. shampoo.conditioner body soap', 'spacyVector': 3 in 1. shower gel. shampoo.conditioner body soap, 'entities': [shampoo.conditioner]}
#
# {'string': '30" HDTV with Amazon Prime Video, Netflix, Roku, standard cable', 'spacyVector': 30" HDTV with Amazon Prime Video, Netflix, Roku, standard cable, 'entities': [Amazon Prime Video, Netflix, Roku]}
#
# {'string': '30" HDTV with HBO Max, Hulu, Netflix, Roku', 'spacyVector': 30" HDTV with HBO Max, Hulu, Netflix, Roku, 'entities': [Hulu, Netflix, Roku]}
#
# {'string': '30" HDTV with HBO Max, premium cable, Fire TV, Amazon Prime Video, Netflix, standard cable, Hulu', 'spacyVector': 30" HDTV with HBO Max, premium cable, Fire TV, Amazon Prime Video, Netflix, standard cable, Hulu, 'entities': [Fire TV, Amazon Prime Video, Netflix, Hulu]}
#
# {'string': '30" HDTV with Roku', 'spacyVector': 30" HDTV with Roku, 'entities': [Roku]}
#
# {'string': '30" HDTV with Roku, Disney+, standard cable, Hulu, Netflix', 'spacyVector': 30" HDTV with Roku, Disney+, standard cable, Hulu, Netflix, 'entities': [Roku, Disney+, Hulu, Netflix]}
#
# {'string': '30" TV with Roku', 'spacyVector': 30" TV with Roku, 'entities': [Roku]}
#
# {'string': '31" HDTV with Roku', 'spacyVector': 31" HDTV with Roku, 'entities': [Roku]}
#
# {'string': '32" HDTV', 'spacyVector': 32" HDTV, 'entities': []}
#
# {'string': '32" HDTV with Amazon Prime Video, Chromecast, Disney+, Hulu, Netflix', 'spacyVector': 32" HDTV with Amazon Prime Video, Chromecast, Disney+, Hulu, Netflix, 'entities': [Amazon Prime Video, Chromecast, Disney+, Hulu, Netflix]}
#
# {'string': '32" HDTV with Amazon Prime Video, Disney+, Hulu, Netflix, Roku', 'spacyVector': 32" HDTV with Amazon Prime Video, Disney+, Hulu, Netflix, Roku, 'entities': [Amazon Prime Video, Disney+, Hulu, Netflix, Roku]}
#
# {'string': '32" HDTV with Amazon Prime Video, Netflix, Roku', 'spacyVector': 32" HDTV with Amazon Prime Video, Netflix, Roku, 'entities': [Amazon Prime Video, Netflix, Roku]}
#
# {'string': '32" HDTV with Amazon Prime Video, Roku', 'spacyVector': 32" HDTV with Amazon Prime Video, Roku, 'entities': [Amazon Prime Video, Roku]}
#
# {'string': '32" HDTV with Apple TV', 'spacyVector': 32" HDTV with Apple TV, 'entities': [Apple TV]}
#
# {'string': '32" HDTV with Disney+, HBO Max, Hulu, Netflix, Amazon Prime Video', 'spacyVector': 32" HDTV with Disney+, HBO Max, Hulu, Netflix, Amazon Prime Video, 'entities': [Disney+, Hulu, Netflix, Amazon Prime Video]}
#
# {'string': '32" HDTV with Disney+, HBO Max, Netflix, Apple TV, Roku, Hulu, Amazon Prime Video', 'spacyVector': 32" HDTV with Disney+, HBO Max, Netflix, Apple TV, Roku, Hulu, Amazon Prime Video, 'entities': [Disney+, Netflix, Apple TV, Roku, Hulu, Amazon Prime Video]}
#
# {'string': '32" HDTV with Disney+, Hulu', 'spacyVector': 32" HDTV with Disney+, Hulu, 'entities': [Disney+, Hulu]}
#
# {'string': '32" HDTV with Fire TV, Hulu, Netflix', 'spacyVector': 32" HDTV with Fire TV, Hulu, Netflix, 'entities': [Fire TV, Hulu, Netflix]}

# %% [markdown]
# ## 5.Manually Correct Any Falsely Identified Entities

# %%
# fetch all amenities that are tied to companies to vet errors
fin_entities = []
for key in list(amenities_catalog.keys()):
  entities = amenities_catalog[key]['entities']
  if entities:
    for entity in entities:
      fin_entities.append(entity.text)

# %%
len(set(fin_entities))
# Out:
# 251

# %%
sorted(list(set(fin_entities)))
# Out:
# ['AEG',
#  'AESOP',
#  'Alba',
#  'Alba Botanica',
#  'Alexa',
#  'Alexa Bluetooth',
#  'Alexa Echos',
#  'All Natural',
#  'Amana',
#  'Amazon',
#  'Amazon Brand',
#  'Amazon Echo',
#  'Amazon Echo w/',
#  'Amazon Essentials Silky Body Wash - Peach',
#  'Amazon Music Unlimited',
#  'Amazon Prime Video',
#  'Anker',
#  'Antique GE',
#  'Apple Home Pod Bluetooth',
#  'Apple HomePod',
#  'Apple Music',
#  'Apple TV',
#  'Argan Oil',
#  'Argon',
#  'Arm & Hammer 3',
#  'Avalon Organics',
#  'Aveda',
#  'Aveeno',
#  'B&D',
#  'BATH &',
#  'Backyard',
#  'Barbecue',
#  'Bars &',
#  'Bath &',
#  'Bath & Body',
#  'Bath & Body Works',
#  'Bath & Bodyworks',
#  'Bath and Body Works',
#  'Beauty & Planet',
#  'Beekman Fresh Air',
#  'Bertazzoni stainless steel',
#  'Bio Botanics',
#  'Bluetooth',
#  'Bluetooth Speakers',
#  'BodyWash & Bar Variety',
#  'Bosch',
#  'Bosch Convection  oven',
#  'Bosch Mini Speed Oven stainless steel',
#  'Bose',
#  'Bose Sound Bar',
#  'Bose SoundLink Color II',
#  'Brand',
#  'Brookstone Bluetooth',
#  'Cafe GE',
#  'Champagne Collection',
#  'Chromecast',
#  'Citrus+Aloe',
#  'Costco',
#  'Costco/Kirkland',
#  'Crowsley',
#  'Delicen Conditioning Shampoo',
#  'Dial / Dove',
#  'Dial Bars/ Liquid Olay',
#  'Dial Dove',
#  'Disney+',
#  'Dove Men +Care & Love Beauty and Planet',
#  'EOS Organics',
#  'EV',
#  'Echo Dot',
#  'Empava',
#  'Epsom',
#  'Equate',
#  'Esa Honeysuckle Conditioner',
#  'Esa Oatmeal Soap',
#  'Every Body Soap & Lotion',
#  'EveryBody',
#  'Fire TV',
#  'Fridgeair',
#  'Fridgidare',
#  'Frigidaire',
#  'Frigidaire - Stainless Steel',
#  'Frigidaire Professional',
#  'Frigidare',
#  'G.E. electric stainless steel electric stove',
#  'GE',
#  'GE Cafe',
#  'GE Profile',
#  'GE Stainless Steel',
#  'Garnier',
#  'General Electric',
#  'General electric electric',
#  'Generic',
#  'Ginger Farms',
#  'Ginger Lilly',
#  'Ginger Lilly Farms',
#  'Ginger Lily Farms',
#  'Ginger Lily Farms Botanical',
#  'Ginger Lily Farms Botanicals',
#  'Ginger Lily Farms Botanicals Organic',
#  'Ginger Lily Farms Botanicals ZeroDerm Advanced',
#  'Ginger Lily Farms Organic Body Wash',
#  'GoodFill',
#  'Goodfellow & Co',
#  'Goodfill',
#  'Goodfill Co',
#  'Google',
#  'Google Bluetooth',
#  'Google Home',
#  'Google Hub Bluetooth',
#  'Green Tea',
#  'Green Tea & Lemongrass Body Wash',
#  'HBO',
#  'HBO Max',
#  'Harman',
#  'Harmon Kardon',
#  'Hen House Bath Co.',
#  'Hotel Brand',
#  'Hotpoint',
#  'Hulu',
#  'Humphreys Street Soap',
#  'IKEA',
#  'ILVE',
#  'Idk stainless steel',
#  'Irish Spring',
#  'J.R. Watkins- Plant Based & Natural',
#  'J.R. Watkins- Plant Based & Natural Green Tea & Aloe',
#  'JBL',
#  'JBL Bluetooth',
#  'Jenn-Air',
#  'Jenn-Air +',
#  'Kenmore Elite Downdraft',
#  'Kenmore stainless steel electric',
#  'Keurig',
#  'Keypad',
#  'Kirkland',
#  'Kitchen Aid',
#  'KitchenAid',
#  "L'Oréal",
#  'LG',
#  'Le Labo',
#  'Local Nashville sustainable & zero',
#  'Loreal',
#  'Luxe',
#  'Magic',
#  'Manuka Honey',
#  'Marhsall',
#  'Maytag',
#  'McKesson',
#  'Mercury',
#  'Microphone Bluetooth',
#  'Miele',
#  'Mini',
#  'Mini Bluetooth',
#  'Mini Fridge Freezer',
#  'Moroccan Oil Repair',
#  'Morrocan Oil Repair',
#  'NA',
#  'Nespresso',
#  'Netflix',
#  'Neutrogena',
#  'Nexus',
#  'Nexxus',
#  'Nintendo Switch',
#  'Nintendo Wii',
#  'Nivea',
#  'Nutrogena',
#  'OGX',
#  'OGX Nourishing + Coconut Milk',
#  'OGX Renewing Moroccan Argan Oil Conditioner',
#  'OGX Renewing Moroccan Argan Oil Shampoo',
#  'Oatmeal Hotel Soap',
#  'Onkyo & Amazon Echo Show',
#  'Onkyo Bluetooth',
#  'Ortizan Bluetooth Lantern',
#  'Palk Audio Bluetooth',
#  'Panteen',
#  'Pantene & Dove Mens',
#  'Pantene Pro V  conditioner',
#  'Pantene Pro V  shampoo',
#  'Pantene Pro-V',
#  'Pantene Pro-V Conditioner',
#  'Pantene Pro-V Shampoo',
#  'Pantene Shampoo',
#  'Pecksnift',
#  'Pioneer',
#  'Pizza Oven stainless steel',
#  'Plaine Products',
#  'Plaint Products',
#  'Polk',
#  'Polk Audio',
#  'Premium Brands',
#  'RAW',
#  'ROAM',
#  'ROAM shampoo',
#  'Roku',
#  'Roots Aromatherapy',
#  'SAMSUNG',
#  'SONY',
#  'STANDARD',
#  'STANDARD stainless steel electric',
#  'Saipua',
#  'Samsung',
#  'Samsung Sound Bar Bluetooth',
#  'Shea Moisture',
#  'Sonons Bluetooth',
#  'Sonos',
#  'Sonos + Google',
#  'Sonos Bluetooth',
#  'Sonos One',
#  'Sony',
#  'Spotify, Pandora & More',
#  'Stainless Steel',
#  'Stainless-Steel',
#  'TCL Bluetooth',
#  'TRESemme',
#  'TRESemme Moisturizing Conditioner',
#  'TREsemme',
#  'Target',
#  'Terra Pure',
#  'Teseme',
#  'The Good Fill',
#  'Thistle Farms Head',
#  'Tivoli Bluetooth',
#  'TreSemme',
#  'Tresemme',
#  'Variety',
#  'Vegan & Cruelty-Free',
#  'Vintage Hotpoint',
#  'Vintage Westinghouse',
#  'Vizio',
#  'Vizio Bluetooth',
#  'Walmart',
#  'Whirlpood',
#  'Whirlpool',
#  'Whirlpool  electric stove',
#  'Whirlpool  stainless steel',
#  'Whirlpool  stainless steel electric',
#  'Whirlpool  stainless steel gas',
#  'Whirlpool - Gas Oven',
#  'Whirpool Gas Range',
#  'Whole Foods',
#  'Whole Foods Lavender',
#  'Wireless',
#  'Xbox One',
#  'Xbox Series X',
#  'Yamaha Sound Bar Bluetooth',
#  'Zogics',
#  'Zogics Organics',
#  'lotion, shampoo & conditioner body soap',
#  'shampoo.conditioner',
#  'smoothtop electric']

# %%
error_ents = [
    'Backyard', 
    'Backyard - Fully', 
    'Barbecue', 
    'Bath &', 
    'Bathtub', 
    'Blender', 
    'Board', 
    'Children', 
    'Dishwasher', 
    'EV', 
    'Keypad', 
    'Microphone Bluetooth',
    'Mini', 
    'Outlet', 
    'Rudy\'s &', 
    'STAINLESS STEEL',
    'Stainless', 
    'Stainless Steel', 
    'Stainless-Steel', 
    'glasstops stainless steel electric']

# %%
# Correct Errors
for key in amenities_catalog.keys():
  amenities_catalog[key]['ents_fin'] = entityCorrections(amenities_catalog[key]['entities'], error_ents)

# %%
# sanity check
amenities_catalog['a50']
# Out:
# {'string': '32" HDTV with Fire TV, Hulu, Netflix',
#  'spacyVector': 32" HDTV with Fire TV, Hulu, Netflix,
#  'entities': [Fire TV, Hulu, Netflix],
#  'ents_fin': [Fire TV, Hulu, Netflix]}

# %% [markdown]
# ## 6.Remove Recognized Entities

# %%
for key in amenities_catalog.keys():
    new_amenity = removeEntities(amenities_catalog[key]['string'], amenities_catalog[key]['ents_fin'])
    amenities_catalog[key]['noEnt_str'] = new_amenity

# %%
# sanity check
amenities_catalog['a230']
# Out:
# {'string': '48" HDTV with Chromecast, Netflix, premium cable',
#  'spacyVector': 48" HDTV with Chromecast, Netflix, premium cable,
#  'entities': [Chromecast, Netflix],
#  'ents_fin': [Chromecast, Netflix],
#  'noEnt_str': '48" HDTV with  premium cable'}

# %%
current_set = []
for key in amenities_catalog.keys():
  current_set.append(amenities_catalog[key]['noEnt_str'])

# %%
len(set(current_set))
# Out:
# 2283

# %% [markdown]
# ## 7.Take Advantage of Available Structure and Remove Numbers or Units of Measurements
#
# * Up to now, the primary focus was to identify and remove brands from product names. Next, any semi-structured amenity names which contain characters like (<font color='red'>**':', '-'**</font>) will be split to capture the keywords. Plus, any product names which contain numbers or units of measurements will be removed.

# %%
current_set = []
for key in amenities_catalog.keys():
  amenities_catalog[key]['noEnt_split_str'] = split_strucute(amenities_catalog[key]['noEnt_str'])
  current_set.append(amenities_catalog[key]['noEnt_split_str'])

# %%
len(set(current_set))
# Out:
# 1663

# %%
current_set = []
for key in amenities_catalog.keys():
  amenities_catalog[key]['noEnt_split_noNum_str'] = remove_number(amenities_catalog[key]['noEnt_split_str'])
  current_set.append(amenities_catalog[key]['noEnt_split_noNum_str'])

# %%
len(set(current_set))
# Out:
# 1382

# %% [markdown]
# ## 8.Apply Typical Text Pre-Processing

# %%
# alphanumeric
for key in amenities_catalog.keys():
  amenities_catalog[key]['alnum'] = alphanumeric(amenities_catalog[key]['noEnt_split_noNum_str'])

# %%
# lowercase
for key in amenities_catalog.keys():
  amenities_catalog[key]['low'] = low_case(amenities_catalog[key]['alnum'])

# %%
# remove stopwords
for key in amenities_catalog.keys():
  amenities_catalog[key]['no_stopwords'] = remove_stopwords(amenities_catalog[key]['low'])

# %%
# stem
for key in amenities_catalog.keys():
  amenities_catalog[key]['stem'] = stem(amenities_catalog[key]['no_stopwords'])

# %%
# sanity check
amenities_catalog['a230']
# Out:
# {'string': '48" HDTV with Chromecast, Netflix, premium cable',
#  'spacyVector': 48" HDTV with Chromecast, Netflix, premium cable,
#  'entities': [Chromecast, Netflix],
#  'ents_fin': [Chromecast, Netflix],
#  'noEnt_str': '48" HDTV with  premium cable',
#  'noEnt_split_str': '48" HDTV with  premium cable',
#  'noEnt_split_noNum_str': '" HDTV with  premium cable',
#  'alnum': 'HDTV with premium cable',
#  'low': 'hdtv with premium cable',
#  'no_stopwords': 'hdtv premium cable',
#  'stem': 'hdtv premium cabl'}

# %%
# sanity check
amenities_catalog['a1500']
# Out:
# {'string': 'Fast wifi – 79 Mbps',
#  'spacyVector': Fast wifi – 79 Mbps,
#  'entities': [],
#  'ents_fin': [],
#  'noEnt_str': 'Fast wifi – 79 Mbps',
#  'noEnt_split_str': 'Fast wifi',
#  'noEnt_split_noNum_str': 'Fast wifi',
#  'alnum': 'Fast wifi',
#  'low': 'fast wifi',
#  'no_stopwords': 'fast wifi',
#  'stem': 'fast wifi'}

# %% [markdown]
# ## 9.Try Semantic Similarity

# %% [markdown]
# ### 9.1.Vectorize Cleaned Amenity Names

# %%
for key in amenities_catalog.keys():
  amenities_catalog[key]['word_vectors']=spacy_vectorizer(amenities_catalog[key]['stem'], nlp_lg).vector

# %% [markdown]
# ### 9.2.Apply KMeans and Validate Clusters

# %%
# build matrix
X_spacy = None

for key in amenities_catalog.keys():
  if X_spacy is None:
    X_spacy = amenities_catalog[key]['word_vectors']
  else:
    X_spacy = np.vstack((X_spacy, amenities_catalog[key]['word_vectors']))

# %%
# sanity check
X_spacy.shape
# Out:
# (3017, 300)

# %% [markdown]
# #### Credits
# * [Selecting the number of clusters with silhouette analysis on KMeans clustering](https://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html)
# * [Stop Using Elbow Method in K-means Clustering, Instead, Use this!](https://towardsdatascience.com/elbow-method-is-not-sufficient-to-find-best-k-in-k-means-clustering-fc820da0631d#:~:text=In%20real%2Dworld%20datasets%2C%20you,of%20clusters%20for%20your%20dataset.)

# %% [markdown]
# #### Supplemental Sources
# * [How to Determine the Optimal K for K-Means?](https://towardsdatascience.com/elbow-method-is-not-sufficient-to-find-best-k-in-k-means-clustering-fc820da0631)

# %% [markdown]
# #### Takeaway
# * **All sizes of K for KMeans fail to meet the following requirements. Therefore, converting each amenity into a semantic word vector with spaCy and clustering fails.**
#   1. For a particular K, all the clusters should have a Silhouette score more than the average score of the dataset (represented by a red dotted line).
#   2. There should not be wide fluctuations in the size of the clusters.

# %%
# find_silhouette(X_spacy, 20, 40, 2) -> None

# %% [markdown]
# ## 10.Alternative: Try String Similarity with Bag of Words (BoW) and TF-IDF

# %% [markdown]
# ### 10.1.Vectorize Cleaned Amenity Names

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

def bow_vectorizer(X, min_n, max_n):
  count_vect = CountVectorizer(ngram_range=(min_n, max_n))
  X_train_counts = count_vect.fit_transform(X)

  return X_train_counts

def tfidf_vectorizer(X, min_n, max_n):
  tfidf_vect = TfidfVectorizer(use_idf=True, ngram_range=(min_n, max_n))
  X_train_tf = tfidf_vect.fit_transform(X)

  return X_train_tf

# strings
X_str = []
for key in amenities_catalog.keys():
  X_str.append(amenities_catalog[key]['stem'])

# %%
X_bow = bow_vectorizer(X_str, 1, 3)

# %%
X_tf = tfidf_vectorizer(X_str, 1, 3)

# %% [markdown]
# #### Takeaway
# * **All sizes of K for KMeans fail to meet the following requirements mentioned above. But, the TF-IDF Vectorization technique appears to yield better results than the Bag of Words Vectorization technique.**

# %% [markdown]
# #### Bag of Words (Unigram, Bigram, and Trigram)

# %%
# find_silhouette(X_bow.toarray(), 20, 40, 2) # best K -> None

# %% [markdown]
# #### TF-IDF

# %%
# find_silhouette(X_tf.toarray(), 20, 40, 2) # best K -> 15

# %% [markdown]
# ## 11.Alternative: Try Cosine Similarity

# %% [markdown]
# ### 11.1.Find Cosine Similarity Among Vectorized Amenities

# %%
from sklearn.metrics.pairwise import cosine_similarity

X_spacy_cos = cosine_similarity(X_spacy)
X_bow_cos = cosine_similarity(X_bow)
X_tf_cos = cosine_similarity(X_tf)

# %% [markdown]
# #### Takeaway
# * **The Bag of Words Vectorization technique at K=16 appears to outperform the other vectorization techniques.**

# %%
# find_silhouette(X_spacy_cos, 20, 40, 2) # best K -> 18

# %%
# find_silhouette(X_bow_cos, 20, 40, 2) # best K -> 16

# %%
# find_silhouette(X_tf_cos, 20, 40, 2) # best K -> 12

# %% [markdown]
# ## 12.Alternative: PCA on Winning Vectorization Technique

# %%
from sklearn.decomposition import PCA
from sklearn.decomposition import TruncatedSVD

def dim_red_PCA(X, n_components=0.85):
  pca = PCA(n_components=n_components, random_state=42)
  X_pca = pca.fit_transform(X)

  return X_pca

def dim_red_truncatedSVD(X, n_components=30):
  svd = TruncatedSVD(n_components=n_components, random_state=42)
  U = svd.fit_transform(X)
  Sigma = svd.singular_values_
  VT = svd.components_

  return U

# %%
X_pca = dim_red_PCA(X_bow_cos)

# %%
X_svd = dim_red_truncatedSVD(X_bow_cos, 30)

# %%
# find_silhouette(X_pca, 15, 40, 1) # best K -> 33 at 95% variance, 25 at 70% variance, 32 at 85% variance

# %%
# find_silhouette(X_svd, 15, 40, 1) # best K -> 29 # WINNING VECTORIZATION TECHNIQUE!!!
find_silhouette(X_svd, 29, 29, 1, True) # best K -> 29 # WINNING VECTORIZATION TECHNIQUE!!!

# %% [markdown]
# ## 13.Export Winning Results

# %%
kmeans = KMeans(n_clusters=29, n_init="auto", random_state=42).fit(X_svd)

for index in range(len(kmeans.labels_)):
  key = 'a'+str(index+1)
  amenities_catalog[key]['cluster'] = kmeans.labels_[index]

amenities = []

for key in amenities_catalog.keys():
  amenity = []
  amenity.append(key)
  amenity.append(amenities_catalog[key]['string'])
  amenity.append(amenities_catalog[key]['stem'])
  amenity.append(amenities_catalog[key]['cluster'])
  amenities.append(amenity)

df = pd.DataFrame(data=amenities, columns=['a_id', 'string', 'stem', 'cluster'])
sorted_df = df.sort_values(by=['cluster', 'string'], ascending=[True, True])

# %%
sorted_df.head(25)
# Out:
#        a_id                                      string         stem  cluster
# 28      a29                          3 in 1 conditioner    condition        0
# 755    a756                   Alba Botanica conditioner    condition        0
# 776    a777                    Amazon Brand conditioner    condition        0
# 809    a810                 Avalon Organics conditioner    condition        0
# 812    a813                           Aveda conditioner    condition        0
# 840    a841              Bath & Body Works  conditioner    condition        0
# 843    a844               Bath & Body Works conditioner    condition        0
# 850    a851            Bath and Body Works  conditioner    condition        0
# 853    a854             Bath and Body Works conditioner    condition        0
# 860    a861  Beauty & Planet (sulfite free) conditioner    condition        0
# 886    a887               Beekman Fresh Air conditioner    condition        0
# 1083  a1084                                 Conditioner    condition        0
# 1088  a1089                          Costco conditioner    condition        0
# 1186  a1187                          Equate conditioner    condition        0
# 1189  a1190     Esa Honeysuckle Conditioner conditioner    condition        0
# 1661  a1662                         Garnier conditioner    condition        0
# 1683  a1684              Ginger Lilly Farms conditioner    condition        0
# 1688  a1689     Ginger Lily Farms Botanical conditioner    condition        0
# 1690  a1691   Ginger Lily Farms Botanicals  conditioner    condition        0
# 1700  a1701               Ginger Lily Farms conditioner    condition        0
# 1707  a1708                 Goodfellow & Co conditioner    condition        0
# 1729  a1730                             H20 conditioner  h condition        0
# 1947  a1948                     Hotel Brand conditioner    condition        0
# 1985  a1986                     It changes. conditioner    condition        0
# 2027  a2028           Kirkland from Costco! conditioner    condition        0

# %%
# # uncomment to export information if needed
# sorted_df.to_csv(path_or_buf='../data/interim/nlp_bow_trigram_31_svd_30.csv', index=False)

# %% [markdown]
# # 14.Get Main Topic per Cluster

# %%
# #uncomment to delete key if present
# for key in amenities_catalog.keys():
#   del amenities_catalog[key]['word_vectors']

# %%
for key in amenities_catalog.keys():
  amenities_catalog[key]['cluster']=sorted_df[sorted_df['a_id']==key]['cluster'].values[0]

# %%
amenities_catalog['a841']
# Out:
# {'string': 'Bath & Body Works  conditioner',
#  'spacyVector': Bath & Body Works  conditioner,
#  'entities': [Bath & Body Works],
#  'ents_fin': [Bath & Body Works],
#  'noEnt_str': 'conditioner',
#  'noEnt_split_str': 'conditioner',
#  'noEnt_split_noNum_str': 'conditioner',
#  'alnum': 'conditioner',
#  'low': 'conditioner',
#  'no_stopwords': 'conditioner',
#  'stem': 'condition',
#  'cluster': 0}

# %%
from collections import Counter

for cluster in sorted_df['cluster'].unique():
  filtered_df = sorted_df[sorted_df['cluster']==cluster]

  amenities = []
  for amenity in filtered_df['a_id'].values:
    amenities.append(amenities_catalog[amenity]['stem'])

  counter = Counter(amenities)

  print('Cluster: {}'.format(cluster))
  for item in counter.most_common():
    print(item)
  print()
# Out:
# Cluster: 0
# ('condition', 53)
# ('h condition', 1)
# ('condition condition', 1)
#
# Cluster: 1
# ('hdtv', 310)
#
# Cluster: 2
# ('fast wifi', 289)
#
# Cluster: 3
# ('refriger', 24)
# ('kitchen aid refriger', 3)
# ('standard refriger', 3)
# ('mini fridg refriger', 2)
# ('frigidair refriger', 2)
# ('kenmor refriger', 2)
# ('whirlpool refriger', 2)
# ('apart refriger', 1)
# ('apart size refriger', 1)
# ('bertazzoni refriger', 1)
# ('boko refriger', 1)
# ('bottom mount refriger', 1)
# ('new refriger refriger', 1)
# ('dedic guest refriger', 1)
# ('e refriger', 1)
# ('filter water avail refriger', 1)
# ('fridgidair refriger', 1)
# ('frigidari refriger', 1)
# ('full size refriger', 1)
# ('applianc refriger', 1)
# ('addit drawer refriger space refriger', 1)
# ('ice water door refriger', 1)
# ('side side refriger', 1)
# ('gallanz refriger', 1)
# ('ge refriger', 1)
# ('idk refriger', 1)
# ('jen air refriger', 1)
# ('ken refriger', 1)
# ('kenmor elit refriger', 1)
# ('kitchenaid refriger', 1)
# ('french door refriger', 1)
# ('stainless refriger', 1)
# ('magic chef refriger', 1)
# ('chef mini refriger', 1)
# ('mini fridg kitchenett refriger', 1)
# ('mini fridg freezer refriger', 1)
# ('nice refriger', 1)
# ('regular refriger', 1)
# ('ice water refriger', 1)
# ('small bigger refriger', 1)
# ('smaller space save refriger', 1)
# ('smeg refriger', 1)
# ('french refriger', 1)
# ('thermador refriger', 1)
# ('unknown refriger', 1)
# ('full freezer refriger', 1)
# ('whirl pool refriger', 1)
# ('ice maker refriger', 1)
# ('worlpol refriger', 1)
#
# Cluster: 4
# ('hdtv hbo', 136)
#
# Cluster: 5
# ('hdtv premium standard cabl', 21)
# ('hdtv fire tv', 6)
# ('hdtv dvd player', 5)
# ('hdtv standard hulu', 5)
# ('hdtv standard premium cabl', 4)
# ('hdtv standard dvd player', 3)
# ('hdtv dvd standard', 3)
# ('hdtv premium standard', 2)
# ('hdtv standard premium', 2)
# ('hdtv dvd standard cabl', 1)
# ('hdtv standard max', 1)
# ('hdtv premium hbo standard cabl', 1)
# ('hdtv standard premium max', 1)
# ('hdtv dvd premium', 1)
# ('hdtv premium fire tv', 1)
# ('hdtv standard premium hbo', 1)
# ('hdtv standard hbo hulu', 1)
# ('hdtv premium dvd standard cabl', 1)
# ('hdtv premium standard hbo', 1)
# ('hdtv premium standard max', 1)
# ('hdtv standard fire tv', 1)
# ('hdtv standard dvd premium cabl', 1)
#
# Cluster: 6
# ('tv', 101)
# ('tv max', 4)
# ('tv premium', 3)
# ('tv hulu', 3)
# ('tv fire tv', 2)
# ('tv dvd', 1)
#
# Cluster: 7
# ('bodi soap', 60)
#
# Cluster: 8
# ('beekman shampoo', 6)
# ('travel size shampoo', 6)
# ('trader shampoo', 3)
# ('organ shampoo', 2)
# ('coconut shampoo', 2)
# ('aussi shampoo', 2)
# ('dove shampoo', 2)
# ('good fill shampoo', 2)
# ('head shoulder shampoo', 2)
# ('luxuri shampoo', 2)
# ('panten shampoo', 2)
# ('plain product shampoo', 2)
# ('public good shampoo', 2)
# ('puraci shampoo', 2)
# ('standard shampoo', 2)
# ('starter set shampoo', 2)
# ('suav shampoo', 2)
# ('trader joe shampoo', 2)
# ('terra pure shampoo', 2)
# ('travel size condit shampoo', 2)
# ('variou shampoo', 2)
# ('arm hammer shower condition shampoo', 1)
# ('botan shampoo', 1)
# ('unscent shampoo', 1)
# ('hygien product locat closet insid shampoo', 1)
# ('oil morocco shampoo', 1)
# ('assort shampoo', 1)
# ('assort travel size hair shampoo provid suppli shampoo', 1)
# ('aveda shampur shampoo', 1)
# ('basic shampoo', 1)
# ('bath bodi work shampoo', 1)
# ('beautycount shampoo', 1)
# ('bergman kelli shampoo', 1)
# ('bode shampoo', 1)
# ('bodi love shampoo', 1)
# ('brand name shampoo', 1)
# ('co bigelow shampoo', 1)
# ('clarifi shampoo shampoo', 1)
# ('dead sea miner shampoo', 1)
# ('dial shampoo', 1)
# ('differ brand shampoo', 1)
# ('differ type shampoo', 1)
# ('dont rememb shampoo', 1)
# ('dove men love beauti planet shampoo', 1)
# ('dove suav product shampoo', 1)
# ('bronner shampoo', 1)
# ('eco shampoo', 1)
# ('esa honey condit shampoo shampoo', 1)
# ('everyon shampoo', 1)
# ('everyon soap shampoo', 1)
# ('four season shampoo', 1)
# ('garnier fructi shampoo', 1)
# ('paul mitchel tea tree shampoo', 1)
# ('therapi nourish bodi wash vegan shampoo', 1)
# ('ginger lili farm citru shampoo', 1)
# ('grown alchemist shampoo', 1)
# ('h therapi shampoo', 1)
# ('herbal essenc shampoo', 1)
# ('honest shampoo', 1)
# ('hotel soap shampoo', 1)
# ('infus shampoo', 1)
# ('chang shampoo', 1)
# ('green tea alo shampoo', 1)
# ('kalhua shampoo', 1)
# ('keratin infus shampoo', 1)
# ('oreal pari shampoo', 1)
# ('la botegga lavend pepermint shampoo', 1)
# ('lelabo shampoo', 1)
# ('wast compani good fill shampoo', 1)
# ('local nashvil sustain store good fill shampoo', 1)
# ('local nashvil compani good fill shampoo', 1)
# ('mark shampoo', 1)
# ('molton brown shampoo', 1)
# ('multipl shampoo', 1)
# ('nativ shampoo', 1)
# ('natur shampoo', 1)
# ('olay shampoo', 1)
# ('old spice shampoo', 1)
# ('oppeal shampoo', 1)
# ('organ coconut oil moistur shampoo shampoo', 1)
# ('organix shampoo', 1)
# ('panten pro v shampoo', 1)
# ('condition shampoo', 1)
# ('panten shampoo condition shampoo', 1)
# ('paraben free shampoo', 1)
# ('paul mitchel shampoo', 1)
# ('per guest need shampoo', 1)
# ('philosophi shampoo', 1)
# ('popular name brand shampoo', 1)
# ('premium shampoo', 1)
# ('puraci natur shampoo', 1)
# ('pureolog shampoo', 1)
# ('roam shampoo', 1)
# ('sampl size shampoo', 1)
# ('sampler size shampoo', 1)
# ('sampl bathroom closet shampoo', 1)
# ('shamp du jour shampoo', 1)
# ('starter bottl avail shampoo', 1)
# ('tbd shampoo', 1)
# ('tresemm deep cleans shampoo shampoo', 1)
# ('tresemm deep cleans shampoo', 1)
# ('tresemmé deep cleans shampoo shampoo', 1)
# ('tresemmé shampoo', 1)
# ('tea tree tingl shampoo', 1)
# ('teetre shampoo', 1)
# ('green tea shampoo', 1)
# ('local sustain shampoo', 1)
# ('local compani focus low wast shampoo', 1)
# ('three one shampoo', 1)
# ('tommi bahama shampoo', 1)
# ('trader joe soap shampoo', 1)
# ('travel well earth consciou shampoo', 1)
# ('travel size condit shampoo condition', 1)
# ('travel size condit shampoo shampoo', 1)
# ('tresem shampoo', 1)
# ('tresemm shampoo', 1)
# ('tresemé shampoo', 1)
# ('vo shampoo', 1)
# ('vari shampoo', 1)
# ('varieti brand shampoo', 1)
# ('varieti shampoo', 1)
# ('variou brand shampoo', 1)
# ('provid starter set luxuri toiletri shampoo', 1)
# ('william roam shampoo', 1)
# ('williamroam shampoo', 1)
# ('young live shampoo', 1)
# ('zealio shampoo', 1)
#
# Cluster: 9
# ('hdtv standard cabl', 86)
#
# Cluster: 10
# ('sound system', 23)
# ('sound system bluetooth aux', 13)
# ('bluetooth sound system', 10)
# ('sound system aux', 5)
# ('alexa bluetooth sound system', 3)
# ('bluetooth speaker bluetooth sound system', 3)
# ('portabl speaker bluetooth sound system', 2)
# ('marshal sound system bluetooth aux', 2)
# ('soundbar bluetooth sound system', 2)
# ('small bluetooth speaker bluetooth sound system', 1)
# ('everi room sound system bluetooth aux', 1)
# ('alexa devic sound system', 1)
# ('alexa sound system', 1)
# ('alexa sound system bluetooth aux', 1)
# ('echo bluetooth sound system', 1)
# ('room bluetooth sound system', 1)
# ('amazon music unlimit sound system', 1)
# ('anerimst sound system bluetooth aux', 1)
# ('anker speaker guest bluetooth sound system', 1)
# ('bluetooth speaker tower bluetooth sound system', 1)
# ('bluetooth speaker sound system bluetooth aux', 1)
# ('bose bluetooth sound system', 1)
# ('bose pro sound system bluetooth aux', 1)
# ('portabl microphon bluetooth sound system', 1)
# ('bose wireless speaker bluetooth sound system', 1)
# ('speaker sound system bluetooth aux', 1)
# ('cd live room sound system', 1)
# ('dock station iphon sound system', 1)
# ('edifi sound system', 1)
# ('home sound system', 1)
# ('kardan bluetooth sound system', 1)
# ('ihom sound system bluetooth aux', 1)
# ('wireless speaker bluetooth sound system', 1)
# ('jambox bluetooth sound system', 1)
# ('karaok player bluetooth sound system', 1)
# ('kaya sound system bluetooth aux', 1)
# ('kenmor sound system', 1)
# ('klipisch bluetooth sound system', 1)
# ('klipsch sound system bluetooth aux', 1)
# ('klipsch five sound system bluetooth aux', 1)
# ('bluetooth bluetooth sound system', 1)
# ('mini amp sound system bluetooth aux', 1)
# ('marshal bluetooth sound system', 1)
# ('marshal speaker bluetooth sound system', 1)
# ('marshal speaker sound system bluetooth aux', 1)
# ('marshal standmor ii bluetooth sound system', 1)
# ('mini portabl speaker bluetooth sound system', 1)
# ('monster boom box sound system bluetooth aux', 1)
# ('onkyo sound system', 1)
# ('onn sound system bluetooth aux', 1)
# ('speaker bluetooth sound system', 1)
# ('record player doubl sound system bluetooth sound system', 1)
# ('audio sound system bluetooth aux', 1)
# ('audio bluetooth sound system', 1)
# ('polk sound system', 1)
# ('portabl bluetooth sound system', 1)
# ('pyle bluetooth receiv home sound bluetooth sound system', 1)
# ('pyle bluetooth sound system', 1)
# ('sono sound system', 1)
# ('sono sound system bluetooth aux', 1)
# ('bluetooth surround bluetooth sound system', 1)
# ('sound dolbi atmo surround bluetooth sound system', 1)
# ('sengl bluetooth sound system', 1)
# ('small blue tooth speaker bluetooth sound system', 1)
# ('requir download app bluetooth sound system', 1)
# ('throughout hous bluetooth sound system', 1)
# ('system bluetooth aux', 1)
# ('connect bluetooth sound system', 1)
# ('tuner tv entertain cabinet bluetooth sound system', 1)
# ('sound bar sound system', 1)
# ('radio record player sound system bluetooth aux', 1)
# ('tower power speaker sound system bluetooth aux', 1)
# ('visio sound system bluetooth aux', 1)
# ('w subwoof sound system bluetooth aux', 1)
# ('andsoundbar bluetooth sound system', 1)
# ('sound bar bluetooth connect sound system bluetooth aux', 1)
#
# Cluster: 11
# ('electr stove', 17)
# ('stove', 11)
# ('ga stove', 7)
# ('induct stove', 4)
# ('bertazzoni ga stove', 2)
# ('burner portabl induct glass stove top induct stove', 1)
# ('burner glass induct stove top induct stove', 1)
# ('burner glass top stove electr stove', 1)
# ('burner induct glass stove top induct stove', 1)
# ('burner induct stove', 1)
# ('countertop oven stove', 1)
# ('hot plate stove', 1)
# ('fridgedair electr stove', 1)
# ('fridgidair stove', 1)
# ('frigdari stove', 1)
# ('frigidair ga stove', 1)
# ('frigidair induct stove', 1)
# ('ga stove ga stove', 1)
# ('ga stove stove', 1)
# ('portabl induct stove', 1)
# ('jen air ga stove', 1)
# ('jenn air electr stove', 1)
# ('kenmor electr stove', 1)
# ('kenmor ga stove', 1)
# ('kitchen aid ga stove', 1)
# ('kitchen aid stove', 1)
# ('ga stove doubl lower oven convect ga stove', 1)
# ('electr plug burner stove', 1)
# ('regular electr stove', 1)
# ('singl burner induct stove', 1)
# ('smooth top electr stove', 1)
# ('standard ga stove', 1)
# ('starndard electr stove', 1)
# ('thermador ga stove', 1)
# ('two burner induct stove', 1)
# ('two cast iron hot plate instead tradit stove stove', 1)
# ('vike ga stove', 1)
# ('whirlpool electr stove', 1)
# ('whirlpool ga stove', 1)
# ('whirlpool stove', 1)
# ('zline ga stove', 1)
#
# Cluster: 12
# ('share outdoor pool', 46)
# ('privat outdoor pool', 16)
# ('share pool', 11)
# ('outdoor pool', 4)
# ('pool', 2)
# ('share outdoor kitchen', 1)
#
# Cluster: 13
# ('game consol', 13)
# ('free driveway park premis', 10)
# ('paid park garag premis', 9)
# ('paid park lot premis', 8)
# ('bbq grill', 7)
# ('free park garag premis', 7)
# ('free park premis', 7)
# ('free residenti garag premis', 7)
# ('indoor fireplac', 7)
# ('share indoor pool', 6)
# ('free carport premis', 5)
# ('privat hot tub', 5)
# ('privat pool', 5)
# ('share hot tub', 5)
# ('ev charger', 4)
# ('paid park premis', 4)
# ('tv dvd player', 3)
# ('', 3)
# ('backyard', 3)
# ('booster seat high chair', 3)
# ('book toy age year old', 3)
# ('book toy age year old year old', 3)
# ('crib', 3)
# ('dryer', 3)
# ('fold convert high chair', 3)
# ('free dryer', 3)
# ('free washer', 3)
# ('pack crib', 3)
# ('privat backyard', 3)
# ('share backyard', 3)
# ('standalon high chair', 3)
# ('washer', 3)
# ('bertazzoni oven', 2)
# ('convect oven microwav combo oven', 2)
# ('book toy age year year year old', 2)
# ('clamp tabl seat high chair', 2)
# ('electr oven', 2)
# ('heat', 2)
# ('high chair', 2)
# ('hot tub', 2)
# ('http', 2)
# ('paid dryer', 2)
# ('paid fold convert high chair', 2)
# ('paid washer', 2)
# ('public share beach access', 2)
# ('trader joe', 2)
# ('size kitchenett separ freezer mini fridg one bedroom refriger', 1)
# ('burner cooktop oven', 1)
# ('compactstov oven', 1)
# ('acondition', 1)
# ('ac', 1)
# ('air condit', 1)
# ('airport shuttl', 1)
# ('altec lans hyrdasound system', 1)
# ('babi bath', 1)
# ('babi monitor', 1)
# ('babi safeti gate', 1)
# ('babysitt recommend', 1)
# ('bake sheet', 1)
# ('barbecu utensil', 1)
# ('bathroom essenti', 1)
# ('bathtub', 1)
# ('bay view', 1)
# ('beach access', 1)
# ('beach essenti', 1)
# ('bed linen', 1)
# ('bed sheet pillow', 1)
# ('bedroom comfort', 1)
# ('bidet', 1)
# ('bike', 1)
# ('blender', 1)
# ('board game', 1)
# ('boat slip', 1)
# ('book read materi', 1)
# ('bosch convect oven', 1)
# ('bottom mount', 1)
# ('bread maker', 1)
# ('breakfast', 1)
# ('build staff', 1)
# ('convect microwav combo oven', 1)
# ('canal view', 1)
# ('carbon monoxid alarm', 1)
# ('ceil fan', 1)
# ('central air condit', 1)
# ('central heat', 1)
# ('chang tabl', 1)
# ('book toy', 1)
# ('book toy age year year year year old', 1)
# ('dinnerwar', 1)
# ('choic formula', 1)
# ('citi skylin view', 1)
# ('clean avail stay', 1)
# ('clean product', 1)
# ('complimentari self park', 1)
# ('concierg', 1)
# ('convect oven oven', 1)
# ('cook basic', 1)
# ('countertop convect oven larg enough pizza oven', 1)
# ('courtyard view', 1)
# ('dedic workspac', 1)
# ('dine tabl', 1)
# ('dish silverwar', 1)
# ('dishwash', 1)
# ('dial orbodi soap', 1)
# ('dri rack cloth', 1)
# ('elev', 1)
# ('essenti', 1)
# ('ethernet connect', 1)
# ('extra pillow blanket', 1)
# ('filter water ice maker refriger', 1)
# ('fire extinguish', 1)
# ('fire pit', 1)
# ('fireplac guard', 1)
# ('first aid kit', 1)
# ('fit center', 1)
# ('free resort access', 1)
# ('free street park', 1)
# ('freezer', 1)
# ('fridgidar oven', 1)
# ('frigidair oven', 1)
# ('full kitchen', 1)
# ('side side lower freezer door refriger', 1)
# ('side side door dispens water filter refriger', 1)
# ('garden view', 1)
# ('gener electr oven', 1)
# ('golf cours view', 1)
# ('guest may place larger item downstair fridg need refriger', 1)
# ('gym', 1)
# ('gym build', 1)
# ('gym nearbi', 1)
# ('hair dryer', 1)
# ('half bigger dorm fridg refriger', 1)
# ('hammock', 1)
# ('hanger', 1)
# ('host greet', 1)
# ('hot water', 1)
# ('hot water kettl', 1)
# ('housekeep', 1)
# ('ice maker water dispens refriger', 1)
# ('indoor pool', 1)
# ('iron', 1)
# ('mini fridg lower level refriger', 1)
# ('jose eber soap', 1)
# ('jose eber', 1)
# ('kayak', 1)
# ('kenmor oven', 1)
# ('keypad', 1)
# ('kitchen', 1)
# ('kitchen aid french door refriger', 1)
# ('kitchenett', 1)
# ('lake access', 1)
# ('lake view', 1)
# ('larg toaster oven fit whole oven', 1)
# ('laundromat nearbi', 1)
# ('lock bedroom door', 1)
# ('lockbox', 1)
# ('long term stay allow', 1)
# ('luggag dropoff allow', 1)
# ('marina view', 1)
# ('aga oven', 1)
# ('microwav', 1)
# ('mini fridg', 1)
# ('mosquito net', 1)
# ('mountain view', 1)
# ('note', 1)
# ('full size big enough refriger', 1)
# ('one singl burner stove', 1)
# ('outdoor dine area', 1)
# ('outdoor furnitur', 1)
# ('outdoor kitchen', 1)
# ('outdoor shower', 1)
# ('outlet cover', 1)
# ('oven griddl cook top four oven', 1)
# ('paid clamp tabl seat high chair', 1)
# ('paid crib', 1)
# ('paid high chair', 1)
# ('paid pack crib', 1)
# ('paid resort access', 1)
# ('paid standalon high chair', 1)
# ('paid street park premis', 1)
# ('paid valet park premis', 1)
# ('park view', 1)
# ('patio balconi', 1)
# ('pet allow', 1)
# ('piano', 1)
# ('ping pong tabl', 1)
# ('pool tabl', 1)
# ('pool toy', 1)
# ('pool view', 1)
# ('portabl air condit', 1)
# ('portabl fan', 1)
# ('portabl heater', 1)
# ('privat entranc', 1)
# ('privat gym', 1)
# ('privat gym build', 1)
# ('privat gym nearbi', 1)
# ('privat live room', 1)
# ('privat outdoor kitchen', 1)
# ('privat patio balconi', 1)
# ('privat sauna', 1)
# ('radiant heat', 1)
# ('record player', 1)
# ('regular oven', 1)
# ('resort access', 1)
# ('resort view', 1)
# ('restaur', 1)
# ('rice maker', 1)
# ('river view', 1)
# ('shade', 1)
# ('safe', 1)
# ('sauna', 1)
# ('secur camera properti', 1)
# ('self', 1)
# ('share gym', 1)
# ('share gym build', 1)
# ('share gym nearbi', 1)
# ('share patio balconi', 1)
# ('share sauna', 1)
# ('shower gel', 1)
# ('singl level home', 1)
# ('small oven stove top oven', 1)
# ('good standard larg sufficiet refriger', 1)
# ('smart lock', 1)
# ('smart speaker withsound system', 1)
# ('smoke alarm', 1)
# ('smoke allow', 1)
# ('sound bar', 1)
# ('stainless steel ice maker water dispens refriger', 1)
# ('standard oven', 1)
# ('standard size oven', 1)
# ('starter set', 1)
# ('suitabl event', 1)
# ('sun lounger', 1)
# ('tabl corner guard', 1)
# ('local compani focus high low wast condition', 1)
# ('toaster', 1)
# ('toaster oven instead larg kitchen space save oven', 1)
# ('toaster oven oven', 1)
# ('toiletri', 1)
# ('trash compactor', 1)
# ('two portabl bluetooth speaker providedsound system', 1)
# ('valley view', 1)
# ('vineyard view', 1)
# ('full oven oven', 1)
# ('waterfront', 1)
# ('use salon product guest may choos whether want normal dri paul mitchel product dri shampoo', 1)
# ('whirlpool oven', 1)
# ('window ac unit', 1)
# ('window guard', 1)
# ('wine glass', 1)
# ('zline oven', 1)
#
# Cluster: 14
# ('beekman bodi soap', 6)
# ('travel size bodi soap', 5)
# ('bodi wash bodi soap', 4)
# ('standard bodi soap', 4)
# ('trader bodi soap', 3)
# ('dove bodi soap', 2)
# ('everyon soap bodi soap', 2)
# ('freshscent bodi soap', 2)
# ('gener bodi soap', 2)
# ('good fill bodi soap', 2)
# ('infus bodi soap', 2)
# ('local bodi soap', 2)
# ('luxuri bodi soap', 2)
# ('multipl bodi soap', 2)
# ('olay bodi wash bodi soap', 2)
# ('organ bodi soap', 2)
# ('public good bodi soap', 2)
# ('roam bodi soap', 2)
# ('suav bodi soap', 2)
# ('terra pure bodi soap', 2)
# ('trader joe soap bodi soap', 2)
# ('vari bodi soap', 2)
# ('variou bodi soap', 2)
# ('local bar bodi soap', 1)
# ('shower soap', 1)
# ('abodi soap', 1)
# ('potpourri soap mani hotel bodi soap', 1)
# ('unscent bodi soap', 1)
# ('hygien product locat closet insid bodi soap', 1)
# ('alo bodi soap', 1)
# ('assort bodi soap', 1)
# ('assort travel size bodi wash soap provid suppli bodi soap', 1)
# ('aussi bodi soap', 1)
# ('bodi work bodi soap', 1)
# ('bar du jour bodi soap', 1)
# ('bar soap provid check bodi soap', 1)
# ('basic bodi soap', 1)
# ('work bodi soap', 1)
# ('bath bodi work bodi soap', 1)
# ('beekman bodi condition hand bodi soap', 1)
# ('beekman goat milk cleans bar bodi soap', 1)
# ('bergman kelli bodi soap', 1)
# ('bode bodi soap', 1)
# ('bodyographi bodi soap', 1)
# ('liquid bodi wash bar soap bodi soap', 1)
# ('co bigelow bodi soap', 1)
# ('choic hypoallergen product mild bodi soap', 1)
# ('clarifi bodi wash bodi soap', 1)
# ('cocoa butter bodi wash bodi soap', 1)
# ('dial bodi soap', 1)
# ('differ brand bodi soap', 1)
# ('differ kind bodi soap', 1)
# ('differ type bodi soap', 1)
# ('dont rememb bodi soap', 1)
# ('dove moistur cream blue chamomil oat milk bodi soap', 1)
# ('dove bar soap bodi soap', 1)
# ('dove bodi wash bodi soap', 1)
# ('dove liquid soap bodi soap', 1)
# ('dove sensit skin bodi soap', 1)
# ('dove bodi dove bar soap bodi soap', 1)
# ('dove individu bar bodi soap', 1)
# ('dove equival qualiti bodi soap', 1)
# ('dove hypoallergen bodi soap', 1)
# ('dr bronner bodi soap', 1)
# ('dr teal bodi soap', 1)
# ('bronner bodi soap', 1)
# ('eucalyptu bodi soap', 1)
# ('eco bodi soap', 1)
# ('green cultur bodi soap', 1)
# ('ecofriendli bodi soap', 1)
# ('eco amen bodi soap', 1)
# ('eco green cultur bodi soap', 1)
# ('salt bodi wash bodi soap', 1)
# ('everyon lavend bodi soap', 1)
# ('everyon bodi soap', 1)
# ('evo bodi soap', 1)
# ('four season bodi soap', 1)
# ('fresh clean bodi soap', 1)
# ('farm bodi soap', 1)
# ('therapi nourish bodi wash vegan bodi soap', 1)
# ('nashvil natur ph balanc sustain bodi soap', 1)
# ('grown alchemist bodi soap', 1)
# ('h therapi bodi soap', 1)
# ('honest bodi soap', 1)
# ('hotel bodi soap', 1)
# ('shower bodi soap', 1)
# ('individualbodi soap', 1)
# ('individu packag premium product bodi soap', 1)
# ('individu wrap bodi soap', 1)
# ('individu wrap hotel size bath bar bodi soap', 1)
# ('irish spring bodi soap', 1)
# ('ivori bodi soap', 1)
# ('kirkland bodi soap', 1)
# ('lux bodi soap', 1)
# ('la botegia franc bodi soap', 1)
# ('ladi speed stick bodi soap', 1)
# ('lelabo bodi soap', 1)
# ('liquid bodi wash bodi soap', 1)
# ('wast compani good fill bodi soap', 1)
# ('local nashvil sustain store good fill bodi soap', 1)
# ('local nashvil compani good fill bodi soap', 1)
# ('local handmad bar soap bodi soap', 1)
# ('local sourc artisan bodi soap', 1)
# ('method bodi soap', 1)
# ('nativ bodi soap', 1)
# ('natur bodi soap', 1)
# ('oil olay bodi soap', 1)
# ('olay ultra moistur bodi soap', 1)
# ('olay bodi soap', 1)
# ('old spice bodi soap', 1)
# ('oppeal delicen manuka honey bodi soap', 1)
# ('organ coconut oil bodi soap bodi soap', 1)
# ('organ ginger lili farm bodi soap', 1)
# ('paraben free bodi soap', 1)
# ('paul mitchel bodi soap', 1)
# ('england bodi soap', 1)
# ('per guest need bodi soap', 1)
# ('philosophi bodi soap', 1)
# ('popular name brand bodi soap', 1)
# ('popular namebrand item bodi soap', 1)
# ('premium bodi soap', 1)
# ('puraci bodi soap', 1)
# ('regular bodi soap', 1)
# ('rose bodi soap', 1)
# ('everyon brand bodi soap', 1)
# ('sampl size bodi soap', 1)
# ('sever bodi soap', 1)
# ('shower gel bodi soap', 1)
# ('kind bodi wash bodi soap', 1)
# ('starter bottl avail bodi soap', 1)
# ('suav bodi wash shower bodi soap', 1)
# ('tbd bodi soap', 1)
# ('trader joe bodi soap', 1)
# ('teetre bodi soap', 1)
# ('green tea bodi soap', 1)
# ('local compani focus high low wast bodi soap', 1)
# ('toe bodi wash bodi soap', 1)
# ('three one bodi soap', 1)
# ('three one shampoo condition bodi gel bodi soap', 1)
# ('tommi bahama bodi soap', 1)
# ('travel well earth consciou bodi soap', 1)
# ('travel bodi soap', 1)
# ('travelwel bodi soap', 1)
# ('tresem bodi soap', 1)
# ('usual dove bodi soap', 1)
# ('varieti bodi soap', 1)
# ('varieti brand bodi soap', 1)
# ('variou brand bodi soap', 1)
# ('variou brand select bodi soap', 1)
# ('provid starter set luxuri bodi soap', 1)
# ('wellb spa rosehip vitamin c bodi soap', 1)
# ('william roam bodi soap', 1)
# ('william roam bodi wash bodi soap', 1)
# ('young live bodi soap', 1)
# ('yuzu hand soap hand lotion bodi soap', 1)
# ('zealio bodi soap', 1)
# ('citru alo bodywash bodi soap', 1)
# ('bodi hand', 1)
#
# Cluster: 15
# ('tv standard cabl', 20)
# ('tv standard', 9)
# ('tv hbo standard cabl', 3)
# ('tv premium cabl', 3)
# ('tv premium standard cabl', 2)
# ('tv standard hulu', 2)
# ('tv dvd standard cabl', 1)
#
# Cluster: 16
# ('hdtv hbo standard cabl', 28)
# ('hdtv hbo hulu', 19)
# ('hdtv hbo premium standard cabl', 13)
# ('hdtv hbo premium', 11)
# ('hdtv hbo standard', 6)
# ('hdtv hbo premium cabl', 4)
# ('hdtv standard hbo', 3)
# ('hdtv hbo dvd player', 2)
# ('hdtv hbo premium standard', 1)
# ('hdtv hbo fire tv', 1)
# ('hdtv hbo standard dvd player', 1)
# ('hdtv hbo premium standard dvd', 1)
# ('hdtv hbo standard premium cabl', 1)
# ('hdtv hbo dvd standard premium', 1)
# ('hdtv hbo premium standard dvd player', 1)
# ('hdtv hbo premium dvd standard', 1)
#
# Cluster: 17
# ('coffe maker', 40)
# ('coffe', 1)
#
# Cluster: 18
# ('cloth storag', 47)
#
# Cluster: 19
# ('beekman condition', 6)
# ('trader condition', 4)
# ('tresemm condition', 3)
# ('vari condition', 3)
# ('organ condition', 2)
# ('coconut condition', 2)
# ('dove condition', 2)
# ('freshscent condition', 2)
# ('paul mitchel tea tree condition', 2)
# ('good fill condition', 2)
# ('green tea condition', 2)
# ('kirkland condition', 2)
# ('luxuri condition', 2)
# ('panten pro v condition', 2)
# ('plain product condition', 2)
# ('puraci condition', 2)
# ('standard condition', 2)
# ('suav condition', 2)
# ('terra pure condition', 2)
# ('travel size condition', 2)
# ('varieti condition', 2)
# ('variou condition', 2)
# ('shampoo condition condition', 1)
# ('alaffia condition', 1)
# ('botan condition', 1)
# ('hygien product locat closet insid condition', 1)
# ('morocco condition', 1)
# ('oil condition', 1)
# ('assort condition', 1)
# ('assort travel size hair condition provid suppli condition', 1)
# ('aussi condition', 1)
# ('basic condition', 1)
# ('beautycount condition', 1)
# ('bergman kelli condition', 1)
# ('bode condition', 1)
# ('bodi love condition', 1)
# ('bodyographi condition', 1)
# ('brand name condition', 1)
# ('co bigelow condition', 1)
# ('coconut moistur condition condition', 1)
# ('condish du jour condition', 1)
# ('dead sea miner condition', 1)
# ('dial condition', 1)
# ('differ brand condition', 1)
# ('differ type condition', 1)
# ('dont rememb condition', 1)
# ('dove men love beauti planet condition', 1)
# ('dove suav product men women condition', 1)
# ('eco condition', 1)
# ('eco botan condition', 1)
# ('four season condition', 1)
# ('local good fill store condition', 1)
# ('garnier fructi condition', 1)
# ('gener condition', 1)
# ('farm condition', 1)
# ('therapi nourish bodi wash vegan condition', 1)
# ('ginger lili farm citru condition', 1)
# ('nashvil hypoallergen natur sustain condition', 1)
# ('grown alchemist condition', 1)
# ('h therapi condition', 1)
# ('head shoulder condition', 1)
# ('herbal essenc condition', 1)
# ('honest condition', 1)
# ('hotel condition', 1)
# ('infus condition', 1)
# ('green tea alo condition', 1)
# ('jose eber champagn collect condition', 1)
# ('keratin infus condition', 1)
# ('oreal pari condition', 1)
# ('lelabo condition', 1)
# ('wast compani good fill condition', 1)
# ('local nashvil sustain store good fill condition', 1)
# ('local nashvil compani good fill condition', 1)
# ('matrix condition', 1)
# ('mark condition', 1)
# ('miscellan condition', 1)
# ('moistur condition condition', 1)
# ('molton brown condition', 1)
# ('multipl brand condition', 1)
# ('nativ condition', 1)
# ('natur condition', 1)
# ('olay condition', 1)
# ('old spice condition', 1)
# ('panten condition', 1)
# ('paraben free condition', 1)
# ('paul mitchel condition', 1)
# ('per guest need condition', 1)
# ('philosophi condition', 1)
# ('popular name brand condition', 1)
# ('premium condition', 1)
# ('public good condition', 1)
# ('puraci natur condition', 1)
# ('pureolog condition', 1)
# ('roam condition', 1)
# ('sampl size condition', 1)
# ('sampler size condition', 1)
# ('sever condition', 1)
# ('shea moistur condition', 1)
# ('alway chang condition', 1)
# ('starter bottl avail condition', 1)
# ('starter set condition', 1)
# ('tbd condition', 1)
# ('tresemm moistur condition', 1)
# ('tresemmé moistur condition condition', 1)
# ('tresemmé condition', 1)
# ('tea tree tingl condition', 1)
# ('teetre condition', 1)
# ('good condition', 1)
# ('three one condition', 1)
# ('three one shampoo condition bodi condition', 1)
# ('tommi bahama condition', 1)
# ('trader joe condition', 1)
# ('trader joe soap condition', 1)
# ('travel well earth consciou condition', 1)
# ('travel toiletri condition', 1)
# ('travelwel condition', 1)
# ('tresem condition', 1)
# ('tresemé condition', 1)
# ('tressem condition', 1)
# ('usual dove condition', 1)
# ('varieti brand condition', 1)
# ('variou brand condition', 1)
# ('variou brand select condition', 1)
# ('provid starter set luxuri toiletri condition', 1)
# ('use multipl brand condition', 1)
# ('william roam condition', 1)
# ('williamroam condition', 1)
# ('zealio condition', 1)
# ('plant base condition infus essenti oil botan extract condition', 1)
#
# Cluster: 20
# ('hdtv premium', 29)
# ('hdtv premium cabl', 20)
# ('hdtv premium hbo', 1)
# ('hdtv premium dvd', 1)
#
# Cluster: 21
# ('stainless steel oven', 18)
# ('oven', 10)
# ('stainless steel refriger', 5)
# ('standard stainless steel oven', 3)
# ('doubl oven stainless steel oven', 2)
# ('frigidair stainless steel oven', 2)
# ('mile purelin convect stainless steel oven', 2)
# ('whirlpool stainless steel oven', 2)
# ('bertazzoni stainless steel oven', 1)
# ('boko convect oven microwav combo stainless steel oven', 1)
# ('convect toaster oven stainless steel oven', 1)
# ('cuisineart countertop toaster air fryer stainless steel oven', 1)
# ('doubl oven made bystainless steel oven', 1)
# ('e oven', 1)
# ('electr stainless steel oven', 1)
# ('electrolux convect stainless steel oven', 1)
# ('electrolux stainless steel oven', 1)
# ('fridgidair stainless steel oven', 1)
# ('frigdair stainless steel oven', 1)
# ('electr cooktop oven rang timer oven light stainless steel oven', 1)
# ('applianc stainless steel oven', 1)
# ('convect stainless steel oven', 1)
# ('ga stainless steel oven', 1)
# ('ga top separ oven stainless steel oven', 1)
# ('kenmor elit stainless steel oven', 1)
# ('kitchen electr stainless steel oven', 1)
# ('kitchenaid stainless steel oven', 1)
# ('stainless steel stainless steel oven', 1)
# ('thermador stainless steel oven', 1)
# ('toaster oven stainless steel oven', 1)
# ('unknown stainless steel oven', 1)
# ('ga burner stainless steel oven', 1)
# ('wolf stainless steel oven', 1)
#
# Cluster: 22
# ('wifi', 30)
# ('free wifi', 1)
# ('pocket wifi', 1)
#
# Cluster: 23
# ('shampoo', 63)
# ('h shampoo', 1)
#
# Cluster: 24
# ('hdtv hulu', 26)
# ('hdtv max', 18)
# ('hdtv withmax', 2)
# ('hdtv dvd', 2)
#
# Cluster: 25
# ('tv hbo', 24)
# ('tv standard hbo', 2)
#
# Cluster: 26
# ('stainless steel ga stove', 13)
# ('stainless steel electr stove', 11)
# ('stainless steel induct stove', 6)
# ('stainless steel stove', 4)
# ('standard stainless steel ga stove', 3)
# ('standard stainless steel electr stove', 2)
# ('whirlpool stainless steel ga stove', 2)
# ('electrolux stainless steel ga stove', 1)
# ('bertazzoni stainless steel ga stove', 1)
# ('fridgidair stainless steel stove', 1)
# ('frigidair stainless steel electr stove', 1)
# ('frigidair stainless steel ga stove', 1)
# ('electr stainless steel electr stove', 1)
# ('electr cooktop larg two timer oven light stainless steel stove', 1)
# ('applianc stainless steel electr stove', 1)
# ('applianc stainless steel ga stove', 1)
# ('idk stainless steel electr stove', 1)
# ('induct cooktop stainless steel stove', 1)
# ('kenmor stainless steel ga stove', 1)
# ('kitchenaid stainless steel electr stove', 1)
# ('mile purelin stainless steel ga stove', 1)
# ('induct stove stainless steel induct stove', 1)
# ('standard stainless steel stove', 1)
# ('thermador stainless steel ga stove', 1)
# ('vike stainless steel ga stove', 1)
# ('kitchen glasstop stainless steel electr stove', 1)
# ('whirlpool stainless steel electr stove', 1)
# ('whirlpool stainless steel induct stove', 1)
# ('whirlpool stainless steel stove', 1)
# ('wolf stainless steel ga stove', 1)
#
# Cluster: 27
# ('hdtv standard', 33)
#
# Cluster: 28
# ('exercis equip', 28)

# %% [markdown]
# # 15.Build Cluster Data Dictionary

# %%
clusters = {
    0: 'Conditioner',
    1: 'TV',
    2: 'WiFi',
    3: 'Refrigerator',
    4: 'TV',
    
    5: 'TV',
    6: 'TV',
    7: 'Body Soap',
    8: 'Shampoo',
    9: 'TV',

    10: 'Sound System',
    11: 'Stove',
    12: 'Pool',
    13: 'Miscellaneous',
    14: 'Body Soap',

    15: 'TV',
    16: 'TV',
    17: 'Coffee Maker',
    18: 'Clothing Storage',
    19: 'Conditioner',

    20: 'TV',
    21: 'Oven',
    22: 'WiFi',
    23: 'Shampoo',
    24: 'TV',
    25: 'TV',

    26:'Stove',
    27:'TV',
    28:'Exercise Equipment',
}


# previous clusters
# clusters = {
#     0: 'Conditioner',
#     1: 'TV',
#     2: 'Wi-Fi',
#     3: 'Backyard or Swimming Pool',
#     4: 'TV',
    
#     5: 'TV',
#     6: 'Shampoo',
#     7: 'Body Soap',
#     8: 'TV',
#     9: 'Swimming Pool',

#     10: 'TV',
#     11: 'Sound System',
#     12: 'Stove',
#     13: 'TV',
#     14: 'Clothing Storage',

#     15: 'Shampoo',
#     16: 'TV',
#     17: 'Conditioner',
#     18: 'Wi-Fi',
#     19: 'TV',

#     20: 'TV',
#     21: 'Refrigerator',
#     22: 'Oven',
#     23: 'Coffee Maker',
#     24: 'TV',
#     25: 'Stove',

#     26: 'TV',
#     27: 'Body Soap',
#     28: 'Free Parking',
#     29: 'Miscellaneous',
#     30: 'Exercise Equipment',

# }

# %%
grouped_clusters = dict()

for key in clusters.keys():
  if clusters[key] in grouped_clusters:
    grouped_clusters[clusters[key]].append(key)
  else:
    grouped_clusters[clusters[key]] = [key]

# %%
grouped_clusters
# Out:
# {'Conditioner': [0, 19],
#  'TV': [1, 4, 5, 6, 9, 15, 16, 20, 24, 25, 27],
#  'WiFi': [2, 22],
#  'Refrigerator': [3],
#  'Body Soap': [7, 14],
#  'Shampoo': [8, 23],
#  'Sound System': [10],
#  'Stove': [11, 26],
#  'Pool': [12],
#  'Miscellaneous': [13],
#  'Coffee Maker': [17],
#  'Clothing Storage': [18],
#  'Oven': [21],
#  'Exercise Equipment': [28]}

# %%
amenity_cluster_mapper = dict()

for key in grouped_clusters.keys():
  amenity_cluster_mapper[key] = sorted_df[sorted_df['cluster'].isin(grouped_clusters[key])]['a_id'].values

# %%
amenity_cluster_mapper_reverse = dict()
for key in amenity_cluster_mapper.keys():
  for a_id in amenity_cluster_mapper[key]:
    amenity_cluster_mapper_reverse[a_id]=key

# %%
# sanity check
amenity_cluster_mapper['Exercise Equipment']
# Out:
# array(['a1203', 'a1204', 'a1205', 'a1206', 'a1207', 'a1208', 'a1209',
#        'a1210', 'a1211', 'a1212', 'a1213', 'a1214', 'a1215', 'a1216',
#        'a1217', 'a1218', 'a1219', 'a1220', 'a1221', 'a1222', 'a1223',
#        'a1224', 'a1225', 'a1226', 'a1227', 'a1228', 'a1229', 'a1230'],
#       dtype=object)

# %%
# sanity check
amenity_cluster_mapper_reverse['a1203']
# Out:
# 'Exercise Equipment'

# %%
# sanity check
amenities_catalog['a1203']
# Out:
# {'string': 'Exercise equipment',
#  'spacyVector': Exercise equipment,
#  'entities': [],
#  'ents_fin': [],
#  'noEnt_str': 'Exercise equipment',
#  'noEnt_split_str': 'Exercise equipment',
#  'noEnt_split_noNum_str': 'Exercise equipment',
#  'alnum': 'Exercise equipment',
#  'low': 'exercise equipment',
#  'no_stopwords': 'exercise equipment',
#  'stem': 'exercis equip',
#  'cluster': 28}

# %% [markdown]
# # 16.Map Generalized Clusters to AirBnB Listings Dataset

# %%
det_list_copy_df = det_list_df.copy(deep=True)
det_list_copy_df = det_list_copy_df[['id', 'amenities']]

# %%
det_list_copy_df.head()
# Out:
#        id                                          amenities
# 0    6422  ["Coffee maker: pour-over coffee", "First aid ...
# 1   59576  ["Books and reading material", "First aid kit"...
# 2   72906  ["First aid kit", "Free street parking", "Fire...
# 3  319705  ["Oven", "Free street parking", "Free parking ...
# 4  289242  ["Oven", "Free street parking", "Free parking ...

# %%
det_list_copy_df.shape
# Out:
# (8127, 2)

# %%
# decode
det_list_copy_df['amenities_decoded'] = det_list_copy_df['amenities'].apply(lambda x: json.loads(x))

# %%
# explode
det_list_copy_df = det_list_copy_df.explode('amenities_decoded')

# %%
det_list_copy_df.head()
# Out:
#      id                                          amenities  \
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
#
#                 amenities_decoded
# 0  Coffee maker: pour-over coffee
# 0                   First aid kit
# 0             Free street parking
# 0               Fire extinguisher
# 0                            Wifi

# %%
det_list_copy_df.shape
# Out:
# (308094, 3)

# %% [markdown]
# ## 16.1 Map Amenity Name in the AirBnB Listings Dataset to Amenity ID

# %%
# make the amenity name the key and a_id the value
amenities_catalog_reverse = {value['string']: key for key, value in amenities_catalog.items()}

# %%
amenities_catalog_reverse['EV charger']
# Out:
# 'a1166'

# %%
len(amenities_catalog_reverse)
# Out:
# 3017

# %%
# map
def a_id_mapper(row):
  a_id=None  
  try:
    a_id = amenities_catalog_reverse[row['amenities_decoded']]
  except:
    a_id = np.nan

  return a_id

det_list_copy_df['a_id'] = det_list_copy_df.apply(lambda x: a_id_mapper(x), axis=1)

# %%
det_list_copy_df.head()
# Out:
#      id                                          amenities  \
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
#
#                 amenities_decoded   a_id
# 0  Coffee maker: pour-over coffee  a1080
# 0                   First aid kit  a1527
# 0             Free street parking  a1575
# 0               Fire extinguisher  a1524
# 0                            Wifi  a2960

# %%
det_list_copy_df[det_list_copy_df.isnull().any(axis=1)]
# Out:
#             id amenities amenities_decoded a_id
# 1520  23145089        []               NaN  NaN

# %% [markdown]
# ## 16.2 Map Amenity ID to Generalized Cluster

# %%
def a_id_cluster_mappers(row):
  amenity_general = None
  try:
      amenity_general = amenity_cluster_mapper_reverse[row['a_id']]
  except:
    amenity_general = np.nan

  return amenity_general

det_list_copy_df['amenity'] = det_list_copy_df.apply(lambda x: a_id_cluster_mappers(x), axis=1)

# %%
det_list_copy_df.head()
# Out:
#      id                                          amenities  \
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
#
#                 amenities_decoded   a_id        amenity
# 0  Coffee maker: pour-over coffee  a1080   Coffee Maker
# 0                   First aid kit  a1527  Miscellaneous
# 0             Free street parking  a1575  Miscellaneous
# 0               Fire extinguisher  a1524  Miscellaneous
# 0                            Wifi  a2960           WiFi

# %% [markdown]
# ## 16.3.Breakout Miscellaneous (Catch-all Cluster)

# %% [markdown]
# ### 16.3.1 Apply Affinity Propogation for Further Clustering and Get Counts of Miscellaneous Amenity Types

# %%
misc_df = sorted_df[sorted_df['cluster']==13]

# %%
misc_df.head()
# Out:
#      a_id                                             string  \
# 7      a8  1/2 size in kitchenette with separate freezer ...
# 12    a13                              2 burner cooktop oven
# 20    a21         20" compact smoothtop electric stove  oven
# 172  a173                       42" TV with Roku, DVD player
# 745  a746                              A Variety conditioner
#
#                                                   stem  cluster
# 7    size kitchenett separ freezer mini fridg one b...       13
# 12                                 burner cooktop oven       13
# 20                                    compactstov oven       13
# 172                                      tv dvd player       13
# 745                                         acondition       13

# %%
## Train new vectorizer focused on miscellaneous cluster
X_bow = bow_vectorizer(misc_df['stem'], 1, 3)
X_bow_cos = cosine_similarity(X_bow)
X_svd = dim_red_truncatedSVD(X_bow_cos, 30)

# %%
from sklearn.cluster import AffinityPropagation

clustering = AffinityPropagation(random_state=42, damping=.65)
clustering.fit(X_svd)
# Out:
# AffinityPropagation(damping=0.65, random_state=42)

# %%
df = pd.DataFrame(clustering.labels_, columns=['new_label'])

# %%
misc_ap_clustered_df = misc_df.reset_index().join(df).sort_values('new_label')

# %%
misc_ap_clustered_df.head()
# Out:
#     index  a_id                             string       stem  cluster  \
# 17    823  a824            BBQ grill: wood-burning  bbq grill       13
# 16    822  a823                     BBQ grill: gas  bbq grill       13
# 15    821  a822                BBQ grill: electric  bbq grill       13
# 14    820  a821  BBQ grill: charcoal, wood-burning  bbq grill       13
# 13    819  a820           BBQ grill: charcoal, gas  bbq grill       13
#
#     new_label
# 17          0
# 16          0
# 15          0
# 14          0
# 13          0

# %%
counts_df = det_list_copy_df['amenities_decoded'].value_counts(dropna=False).reset_index()
counts_filtered_df = counts_df[counts_df['index'].isin(misc_ap_clustered_df['string'].values)]
counts_filtered_df = counts_filtered_df.rename(columns={'index':'string', 'amenities_decoded':'count'})

# %%
misc_counts_ap_df = misc_ap_clustered_df.merge(counts_filtered_df, how='left', on='string')

# %%
misc_counts_ap_df.head()
# Out:
#    index  a_id                             string       stem  cluster  \
# 0    823  a824            BBQ grill: wood-burning  bbq grill       13
# 1    822  a823                     BBQ grill: gas  bbq grill       13
# 2    821  a822                BBQ grill: electric  bbq grill       13
# 3    820  a821  BBQ grill: charcoal, wood-burning  bbq grill       13
# 4    819  a820           BBQ grill: charcoal, gas  bbq grill       13
#
#    new_label  count
# 0          0      4
# 1          0    236
# 2          0     10
# 3          0      1
# 4          0     11

# %%
# export and manually label newly formed clusters

# personal directory
# misc_counts_ap_df.to_csv(path_or_buf='./misc_counts_ap_df.csv', index=False)

# GitHub directory
misc_counts_ap_df.to_csv(path_or_buf='../data/interim/misc_counts_ap_df.csv', index=False)

# %% [markdown]
# ### 16.3.2. Manually Discard Remaining Entities and Apply Labels to Clusters

# %%
# import manually labeled and newly formed clusters

# personal directory
# misc_clusters_labeled_df = pd.read_csv('./misc_counts_ap_labeled_df.csv')

# GitHub directory
misc_clusters_labeled_df = pd.read_csv('../data/interim/misc_counts_ap_labeled_df.csv')

# %%
misc_clusters_labeled_filtered_df = misc_clusters_labeled_df[misc_clusters_labeled_df['keep']==1]

# %%
misc_clusters_labeled_filtered_df.head()
# Out:
#    index  a_id                             string       stem  cluster  \
# 0    823  a824            BBQ grill: wood-burning  bbq grill       13
# 1    822  a823                     BBQ grill: gas  bbq grill       13
# 2    821  a822                BBQ grill: electric  bbq grill       13
# 3    820  a821  BBQ grill: charcoal, wood-burning  bbq grill       13
# 4    819  a820           BBQ grill: charcoal, gas  bbq grill       13
#
#    new_label  count  keep new_cluster
# 0          0      4   1.0         BBQ
# 1          0    236   1.0         BBQ
# 2          0     10   1.0         BBQ
# 3          0      1   1.0         BBQ
# 4          0     11   1.0         BBQ

# %%
grouped_misc = misc_clusters_labeled_filtered_df.groupby('new_cluster')['a_id'].apply(list).reset_index()

# %%
misc_dict = {}

for index, row in grouped_misc.iterrows():
  misc_dict[row['new_cluster']]=row['a_id']

# %%
misc_dict_reverse = dict()

for key in misc_dict.keys():
  for a_id in misc_dict[key]:
    misc_dict_reverse[a_id]=key

# %%
# sanity check
misc_dict['BBQ']
# Out:
# ['a824', 'a823', 'a822', 'a821', 'a820', 'a819', 'a818']

# %%
# sanity check
misc_dict_reverse['a820']
# Out:
# 'BBQ'

# %%
# replace values in main df
def misc_mapper(row, dict_rev):
  amenity_general = None
  try:
      amenity_general = dict_rev[row['a_id']]
  except:
    amenity_general = row['amenity'] # Miscellaneous will be a placeholder to discard if remaining later

  return amenity_general

det_list_copy_df['amenity'] = det_list_copy_df.apply(lambda x: misc_mapper(x, misc_dict_reverse), axis=1)

# %%
det_list_copy_df.head()
# Out:
#      id                                          amenities  \
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
#
#                 amenities_decoded   a_id            amenity
# 0  Coffee maker: pour-over coffee  a1080       Coffee Maker
# 0                   First aid kit  a1527      First Aid Kit
# 0             Free street parking  a1575       Free Parking
# 0               Fire extinguisher  a1524  Fire Extinguisher
# 0                            Wifi  a2960               WiFi

# %%
det_list_copy_df.shape
# Out:
# (308094, 5)

# %%
det_list_copy_df[det_list_copy_df['amenity']=='BBQ'].sample()
# Out:
#             id                                          amenities  \
# 4301  50728773  ["First aid kit", "Oven", "Shared outdoor pool...
#
#      amenities_decoded  a_id amenity
# 4301         BBQ grill  a818     BBQ

# %%
# drop miscellaneous rows
det_list_final_df = det_list_copy_df[det_list_copy_df['amenity']!='Miscellaneous']

# %%
det_list_final_df.head()
# Out:
#      id                                          amenities  \
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
# 0  6422  ["Coffee maker: pour-over coffee", "First aid ...
#
#                 amenities_decoded   a_id            amenity
# 0  Coffee maker: pour-over coffee  a1080       Coffee Maker
# 0                   First aid kit  a1527      First Aid Kit
# 0             Free street parking  a1575       Free Parking
# 0               Fire extinguisher  a1524  Fire Extinguisher
# 0                            Wifi  a2960               WiFi

# %%
det_list_final_df.shape
# Out:
# (281823, 5)

# %% [markdown]
# # 17.OHE Amenities

# %%
final_df_copy = det_list_final_df.copy(deep=True)

# %%
columns = det_list_final_df['amenity'].value_counts().index.values
columns
# Out:
# array(['Free Parking', 'Coffee Maker', 'Patio or Balcony', 'WiFi',
#        'Smoke Alarm', 'Air Conditioning', 'TV', 'Heating', 'Essentials',
#        'Kitchen', 'Hair Dryer', 'Long Term Stays Allowed', 'Iron',
#        'Hangers', 'Shampoo', 'Washer', 'Refrigerator', 'Diningware',
#        'Hot Water', 'Microwave', 'Fire Extinguisher', 'Dryer',
#        'Carbon Monoxide Alarm', 'Bed Linens', 'Self Check-in', 'Oven',
#        'Cooking Basics', 'Stove', 'Dishwasher', 'Private Entrance',
#        'First Aid Kit', 'Extra Pillows and Blankets',
#        'Dedicated Workspace', 'Surveillance', 'Freezer', 'Body Soap',
#        'Backyard', 'Clothing Storage', 'Wine Glasses', 'Conditioner',
#        'Toaster', 'Cleaning Products', 'Dining Table', 'Keypad', 'BBQ',
#        'Shades', 'Luggage Dropoff Allowed', 'Smart Lock', 'Pets Allowed',
#        'Baby Crib', 'Pool', 'Gym', 'Blender', 'Fire Pit', 'Elevator',
#        'Lockbox', 'Fireplace', 'Paid Parking', 'Laundromat Nearby',
#        'Exercise Equipment', 'City Skyline View', 'High Chair', 'Hot Tub',
#        'Toys', 'Sound System', 'Beach Access', 'EV Charger',
#        'Garden View', 'Courtyard View', 'River View', 'Pool View',
#        'Park View', 'Resort View', 'Mountain View', 'Valley View',
#        'Lake View', 'Golf Course View', 'Marina View', 'Canal View',
#        'Bay View', 'Vineyard View'], dtype=object)

# %%
grouped_final_df_copy = final_df_copy.groupby('id')['amenity'].apply(list).reset_index()

# %%
OHE_listings = []

for listing in grouped_final_df_copy['id'].values:
  amenities = grouped_final_df_copy[grouped_final_df_copy['id']==listing]['amenity'].values[0]

  OHE_amenities = []
  for column in columns:
    if column in amenities:
      OHE_amenities.append(1)
    else:
      OHE_amenities.append(0)

  OHE_listings.append(OHE_amenities)

# %%
listing_ids_df = pd.DataFrame(grouped_final_df_copy['id'].values, columns=['id'])
OHE_listings_df = pd.DataFrame(OHE_listings, columns=columns)

# %%
final_df = listing_ids_df.join(OHE_listings_df)

# %%
final_df.shape
# Out:
# (8127, 82)

# %%
sample = final_df.sample()
sample_index = sample.index

# %%
sample
# Out:
#             id  Free Parking  Coffee Maker  Patio or Balcony  WiFi  \
# 3868  49566982             1             1                 0     1
#
#       Smoke Alarm  Air Conditioning  TV  Heating  Essentials  ...  Park View  \
# 3868            1                 1   1        1           1  ...          0
#
#       Resort View  Mountain View  Valley View  Lake View  Golf Course View  \
# 3868            0              0            0          0                 0
#
#       Marina View  Canal View  Bay View  Vineyard View
# 3868            0           0         0              0
#
# [1 rows x 82 columns]

# %%
grouped_final_df_copy.iloc[sample_index]['amenity'].values[0]
# Out:
# ['Oven',
#  'Free Parking',
#  'Free Parking',
#  'Fire Extinguisher',
#  'WiFi',
#  'Conditioner',
#  'Hair Dryer',
#  'Body Soap',
#  'Air Conditioning',
#  'Shampoo',
#  'Cooking Basics',
#  'Toaster',
#  'Private Entrance',
#  'Washer',
#  'Microwave',
#  'Dishwasher',
#  'Long Term Stays Allowed',
#  'Extra Pillows and Blankets',
#  'Heating',
#  'Carbon Monoxide Alarm',
#  'Hangers',
#  'Shades',
#  'Clothing Storage',
#  'Fireplace',
#  'Essentials',
#  'Wine Glasses',
#  'Dryer',
#  'Freezer',
#  'Diningware',
#  'Iron',
#  'Self Check-in',
#  'Dedicated Workspace',
#  'Coffee Maker',
#  'Bed Linens',
#  'TV',
#  'Stove',
#  'Smoke Alarm',
#  'City Skyline View',
#  'Kitchen',
#  'Smart Lock']

# %%
# personal directory
# final_df.to_csv(path_or_buf='./OHE_amenities_nashville.csv', index=False)

# GitHub directory
final_df.to_csv(path_or_buf='../data/processed/OHE_amenities_nashville.csv', index=False)

# %%
# Final results -> 28 homogeneous clusters after round 1 of clustering, 53 homogeneous clusters after round 2 of clustering, 81 total clusters
